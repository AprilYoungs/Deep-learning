# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# /Users/Young/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    with tf.name_scope("inputs"):
        input_real = tf.placeholder(tf.float32, [None, image_width, image_height, image_channels], name='input_real')
        input_z = tf.placeholder(tf.float32, [None, z_dim], name='input_z')
        lr = tf.placeholder(tf.float32, name='learning_rate')

    return input_real, input_z, lr


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    alpha = 0.1
    with tf.variable_scope('discriminator', reuse=reuse):
        conv1 = tf.layers.conv2d(images, 64, 5,strides=2, padding='same',
                                 use_bias=False,
                                 activation=None, 
                                 kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        conv1 = tf.layers.batch_normalization(conv1, training=True)
        conv1 = tf.maximum(conv1*alpha, conv1)
        #now 14*14*64
        
        conv2 = tf.layers.conv2d(conv1, 128, 5,strides=2, padding='same', 
                                 use_bias=False,
                                 activation=None,
                                 kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        conv2 = tf.layers.batch_normalization(conv2, training=True)
        conv2 = tf.maximum(conv2*alpha, conv2)
        #now 7*7*128
        
        flat = tf.reshape(conv2, [-1, 7*7*128])
        logit = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logit)

    return out, logit


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    alpha = 0.1
    with tf.variable_scope("generator", reuse= not is_train):
        conv1 = tf.layers.dense(z, 7*7*128, use_bias=False)
        conv1 = tf.layers.batch_normalization(conv1, training=is_train)
        conv1 = tf.reshape(conv1, [-1, 7, 7, 128])
        conv1 = tf.maximum(conv1*alpha, conv1)
        #now 7*7*128
        
        conv2 = tf.layers.conv2d_transpose(conv1, 64, 5, strides=2, 
                                           use_bias=False,
                                           padding="same",
                                           kernel_initializer=tf.contrib.layers.xavier_initializer_conv2d())
        conv2 = tf.layers.batch_normalization(conv2, training=is_train)
        conv2 = tf.maximum(conv2*alpha, conv2)
        #now 14*14*64
        
        output = tf.layers.conv2d_transpose(conv2, out_channel_dim, 5, strides=2, padding='same')
        output = tf.tanh(output)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    with tf.name_scope('loss'):
        
        g_model = generator(input_z, out_channel_dim, is_train=True)
        d_model_real,d_logit_real = discriminator(input_real, reuse=False)
        d_model_fake,d_logit_fake = discriminator(g_model, reuse=True)
        
        
        d_loss_real = tf.reduce_mean(
            tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_real, labels=tf.ones_like(d_logit_real)*0.9))
        d_loss_fake = tf.reduce_mean(
            tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_fake, labels=tf.zeros_like(d_logit_fake)))        
        g_loss = tf.reduce_mean(
            tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logit_fake, labels=tf.ones_like(d_logit_fake)))
        
        d_loss = d_loss_real +  d_loss_fake
        
    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    variable_list = tf.trainable_variables()
    var_d = [var for var in variable_list if var.name.startswith('discriminator')]
    var_g = [var for var in variable_list if var.name.startswith('generator')]
    
    with tf.name_scope('optimizer'):
        with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
            d_opt = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=beta1).minimize(d_loss, var_list=var_d)
            g_opt = tf.train.AdamOptimizer(learning_rate=learning_rate, beta1=beta1).minimize(g_loss, var_list=var_g)
    
    return d_opt, g_opt

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    image_width, image_height, image_channels = data_shape[1:]
    input_real, input_z, lr = model_inputs(image_width, image_height, image_channels, z_dim)
    d_loss, g_loss = model_loss(input_real, input_z, image_channels)
    g_opt, d_opt = model_opt(d_loss, g_loss, lr, beta1)
    
    writer_dis = tf.summary.scalar('discrimitor_loss', d_loss)
    writer_gen = tf.summary.scalar('generator_loss', g_loss)
    
    summary_dir = '/tmp/face_generation/'
    file_dis = tf.summary.FileWriter(summary_dir+'discrimitor', 
                                     graph=tf.get_default_graph())
    file_gen = tf.summary.FileWriter(summary_dir+'generator')
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        step = 0
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                example_z = np.random.uniform(-1, 1, size=[batch_size, z_dim])
                
                batch_images *= 2
                feed_dict = {input_real: batch_images,
                             input_z: example_z,
                             lr: learning_rate
                             }
                _ = sess.run(d_opt, feed_dict=feed_dict)
                _ = sess.run(g_opt, feed_dict=feed_dict)
                
                if step % 10 == 0:
                    feed_dict = {input_real: batch_images,
                                 input_z: example_z}
                    dis_loss,gen_loss,sum_dis,sum_gen = sess.run([d_loss,g_loss,writer_dis,writer_gen],
                                                                 feed_dict=feed_dict)
                    file_dis.add_summary(sum_dis, step)
                    file_gen.add_summary(sum_gen, step)
                    
                    print("Epoch {}/{},".format(epoch_i+1,epoch_count),
                          "discrimitor loss:{:.4f}".format(dis_loss),
                           "generator loss:{:.4f}".format(gen_loss))
                    
                if step % 100 == 0:
                    show_generator_output(sess, 25, input_z, image_channels, data_image_mode)
                    
                step += 1

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2, discrimitor loss:1.2375 generator loss:0.6832
# Epoch 1/2, discrimitor loss:0.4789 generator loss:2.5074
# Epoch 1/2, discrimitor loss:0.4731 generator loss:2.6743
# Epoch 1/2, discrimitor loss:0.4432 generator loss:3.0826
# Epoch 1/2, discrimitor loss:0.4654 generator loss:2.6754
# Epoch 1/2, discrimitor loss:0.4174 generator loss:3.1847
# Epoch 1/2, discrimitor loss:0.3937 generator loss:3.6584
# Epoch 1/2, discrimitor loss:0.4285 generator loss:3.7947
# Epoch 1/2, discrimitor loss:0.4842 generator loss:3.1974
# Epoch 1/2, discrimitor loss:0.4879 generator loss:2.9404
# Epoch 1/2, discrimitor loss:0.5008 generator loss:2.5363
# Epoch 1/2, discrimitor loss:1.0739 generator loss:5.2035
# Epoch 1/2, discrimitor loss:0.4764 generator loss:2.3631
# Epoch 1/2, discrimitor loss:0.6165 generator loss:2.0055
# Epoch 1/2, discrimitor loss:0.5426 generator loss:2.4020
# Epoch 1/2, discrimitor loss:1.3700 generator loss:0.6225
# Epoch 1/2, discrimitor loss:0.5829 generator loss:2.0899
# Epoch 1/2, discrimitor loss:0.8859 generator loss:0.9678
# Epoch 1/2, discrimitor loss:0.6607 generator loss:1.6087
# Epoch 1/2, discrimitor loss:0.6025 generator loss:2.4869
# Epoch 1/2, discrimitor loss:0.6173 generator loss:1.8194
# Epoch 1/2, discrimitor loss:0.6167 generator loss:2.2088
# Epoch 1/2, discrimitor loss:0.6730 generator loss:2.5508
# Epoch 1/2, discrimitor loss:0.8067 generator loss:1.0946
# Epoch 1/2, discrimitor loss:0.8347 generator loss:1.0305
# Epoch 1/2, discrimitor loss:0.6228 generator loss:1.9090
# Epoch 1/2, discrimitor loss:0.6158 generator loss:2.0587
# Epoch 1/2, discrimitor loss:0.6424 generator loss:1.6739
# Epoch 1/2, discrimitor loss:0.6001 generator loss:1.7290
# Epoch 1/2, discrimitor loss:0.9596 generator loss:3.2332
# Epoch 1/2, discrimitor loss:0.6290 generator loss:1.9456
# Epoch 1/2, discrimitor loss:0.6278 generator loss:2.0918
# Epoch 1/2, discrimitor loss:0.6699 generator loss:1.7428
# Epoch 1/2, discrimitor loss:0.9713 generator loss:3.0672
# Epoch 1/2, discrimitor loss:0.8218 generator loss:1.1655
# Epoch 1/2, discrimitor loss:0.6740 generator loss:1.7067
# Epoch 1/2, discrimitor loss:0.6607 generator loss:2.0104
# Epoch 1/2, discrimitor loss:0.6749 generator loss:1.7756
# Epoch 1/2, discrimitor loss:0.5936 generator loss:2.2509
# Epoch 1/2, discrimitor loss:1.2253 generator loss:3.5457
# Epoch 1/2, discrimitor loss:0.6468 generator loss:2.8258
# Epoch 1/2, discrimitor loss:0.6241 generator loss:1.8544
# Epoch 1/2, discrimitor loss:0.6467 generator loss:2.9986
# Epoch 1/2, discrimitor loss:0.6455 generator loss:2.1287
# Epoch 1/2, discrimitor loss:0.7044 generator loss:1.3896
# Epoch 1/2, discrimitor loss:0.6309 generator loss:2.0001
# Epoch 1/2, discrimitor loss:0.6292 generator loss:2.1345
# Epoch 1/2, discrimitor loss:0.6339 generator loss:2.1780
# Epoch 1/2, discrimitor loss:0.6806 generator loss:2.9994
# Epoch 1/2, discrimitor loss:0.6039 generator loss:2.6111
# Epoch 1/2, discrimitor loss:0.6408 generator loss:1.9098
# Epoch 1/2, discrimitor loss:0.6210 generator loss:1.6293
# Epoch 1/2, discrimitor loss:0.6813 generator loss:2.1840
# Epoch 1/2, discrimitor loss:0.7194 generator loss:2.3632
# Epoch 1/2, discrimitor loss:0.7291 generator loss:1.2757
# Epoch 1/2, discrimitor loss:0.7088 generator loss:1.3105
# Epoch 1/2, discrimitor loss:0.6981 generator loss:2.6369
# Epoch 1/2, discrimitor loss:0.5953 generator loss:2.0358
# Epoch 1/2, discrimitor loss:0.7046 generator loss:2.4515
# Epoch 1/2, discrimitor loss:0.6099 generator loss:2.1461
# Epoch 1/2, discrimitor loss:0.6865 generator loss:1.4576
# Epoch 1/2, discrimitor loss:0.6558 generator loss:2.2556
# Epoch 1/2, discrimitor loss:0.6082 generator loss:1.9038
# Epoch 1/2, discrimitor loss:0.6500 generator loss:2.8214
# Epoch 1/2, discrimitor loss:0.7637 generator loss:2.5877
# Epoch 1/2, discrimitor loss:0.9128 generator loss:0.9418
# Epoch 1/2, discrimitor loss:0.6117 generator loss:2.1469
# Epoch 1/2, discrimitor loss:0.6261 generator loss:2.6241
# Epoch 1/2, discrimitor loss:0.6400 generator loss:2.5438
# Epoch 1/2, discrimitor loss:0.5951 generator loss:1.9214
# Epoch 1/2, discrimitor loss:0.7699 generator loss:1.2264
# Epoch 1/2, discrimitor loss:0.9838 generator loss:0.8704
# Epoch 1/2, discrimitor loss:1.0307 generator loss:0.7965
# Epoch 1/2, discrimitor loss:0.6342 generator loss:1.6270
# Epoch 1/2, discrimitor loss:0.5751 generator loss:2.5543
# Epoch 1/2, discrimitor loss:0.6104 generator loss:2.8155
# Epoch 1/2, discrimitor loss:0.6291 generator loss:2.0894
# Epoch 1/2, discrimitor loss:0.6052 generator loss:2.4481
# Epoch 1/2, discrimitor loss:0.6486 generator loss:1.8401
# Epoch 1/2, discrimitor loss:0.6783 generator loss:1.4682
# Epoch 1/2, discrimitor loss:0.6053 generator loss:2.0939
# Epoch 1/2, discrimitor loss:0.6596 generator loss:1.9546
# Epoch 1/2, discrimitor loss:0.5782 generator loss:2.1003
# Epoch 1/2, discrimitor loss:0.5915 generator loss:2.0270
# Epoch 1/2, discrimitor loss:0.5947 generator loss:2.4059
# Epoch 1/2, discrimitor loss:0.6171 generator loss:2.0658
# Epoch 1/2, discrimitor loss:0.6992 generator loss:2.4925
# Epoch 1/2, discrimitor loss:0.6188 generator loss:1.7550
# Epoch 1/2, discrimitor loss:0.7911 generator loss:1.1784
# Epoch 1/2, discrimitor loss:0.6468 generator loss:1.6335
# Epoch 1/2, discrimitor loss:0.6153 generator loss:2.2234
# Epoch 1/2, discrimitor loss:0.5770 generator loss:1.9681
# Epoch 1/2, discrimitor loss:0.7319 generator loss:1.3163
# Epoch 1/2, discrimitor loss:1.0800 generator loss:0.8364
# Epoch 2/2, discrimitor loss:0.6828 generator loss:1.7592
# Epoch 2/2, discrimitor loss:0.6889 generator loss:1.4399
# Epoch 2/2, discrimitor loss:0.6111 generator loss:1.8676
# Epoch 2/2, discrimitor loss:0.6134 generator loss:1.9397
# Epoch 2/2, discrimitor loss:0.6615 generator loss:1.6039
# Epoch 2/2, discrimitor loss:0.6616 generator loss:1.8550
# Epoch 2/2, discrimitor loss:0.6425 generator loss:1.9925
# Epoch 2/2, discrimitor loss:0.6551 generator loss:2.3376
# Epoch 2/2, discrimitor loss:0.7107 generator loss:2.5275
# Epoch 2/2, discrimitor loss:0.6008 generator loss:2.0027
# Epoch 2/2, discrimitor loss:0.6071 generator loss:2.5513
# Epoch 2/2, discrimitor loss:0.6280 generator loss:2.5504
# Epoch 2/2, discrimitor loss:0.6744 generator loss:2.4681
# Epoch 2/2, discrimitor loss:0.5880 generator loss:2.1812
# Epoch 2/2, discrimitor loss:0.9726 generator loss:3.4009
# Epoch 2/2, discrimitor loss:0.6140 generator loss:2.5117
# Epoch 2/2, discrimitor loss:0.6218 generator loss:1.6237
# Epoch 2/2, discrimitor loss:0.6283 generator loss:2.7052
# Epoch 2/2, discrimitor loss:0.5669 generator loss:2.2644
# Epoch 2/2, discrimitor loss:0.8677 generator loss:3.2306
# Epoch 2/2, discrimitor loss:0.5976 generator loss:2.0922
# Epoch 2/2, discrimitor loss:0.6750 generator loss:2.5604
# Epoch 2/2, discrimitor loss:0.6400 generator loss:1.5234
# Epoch 2/2, discrimitor loss:0.5956 generator loss:2.2979
# Epoch 2/2, discrimitor loss:0.6807 generator loss:2.0971
# Epoch 2/2, discrimitor loss:0.5888 generator loss:2.1094
# Epoch 2/2, discrimitor loss:0.5909 generator loss:1.9908
# Epoch 2/2, discrimitor loss:0.5780 generator loss:1.9895
# Epoch 2/2, discrimitor loss:0.5658 generator loss:2.3797
# Epoch 2/2, discrimitor loss:0.6412 generator loss:1.7271
# Epoch 2/2, discrimitor loss:0.6140 generator loss:1.9287
# Epoch 2/2, discrimitor loss:0.6010 generator loss:2.6155
# Epoch 2/2, discrimitor loss:0.6099 generator loss:1.6923
# Epoch 2/2, discrimitor loss:0.5660 generator loss:2.5432
# Epoch 2/2, discrimitor loss:0.6904 generator loss:2.7981
# Epoch 2/2, discrimitor loss:0.5802 generator loss:1.9943
# Epoch 2/2, discrimitor loss:0.6273 generator loss:1.6280
# Epoch 2/2, discrimitor loss:0.5744 generator loss:1.9100
# Epoch 2/2, discrimitor loss:0.5737 generator loss:2.6544
# Epoch 2/2, discrimitor loss:0.5605 generator loss:1.9682
# Epoch 2/2, discrimitor loss:0.6424 generator loss:1.5247
# Epoch 2/2, discrimitor loss:0.5474 generator loss:2.0554
# Epoch 2/2, discrimitor loss:0.6839 generator loss:2.7612
# Epoch 2/2, discrimitor loss:0.5869 generator loss:1.9154
# Epoch 2/2, discrimitor loss:0.6177 generator loss:1.7583
# Epoch 2/2, discrimitor loss:0.6861 generator loss:1.4972
# Epoch 2/2, discrimitor loss:0.5441 generator loss:2.0141
# Epoch 2/2, discrimitor loss:0.5427 generator loss:1.9966
# Epoch 2/2, discrimitor loss:0.8084 generator loss:1.1516
# Epoch 2/2, discrimitor loss:0.5708 generator loss:2.5296
# Epoch 2/2, discrimitor loss:0.5952 generator loss:2.4790
# Epoch 2/2, discrimitor loss:0.6820 generator loss:1.3886
# Epoch 2/2, discrimitor loss:0.5869 generator loss:1.9077
# Epoch 2/2, discrimitor loss:0.5462 generator loss:2.0879
# Epoch 2/2, discrimitor loss:0.6119 generator loss:3.0900
# Epoch 2/2, discrimitor loss:0.5957 generator loss:2.2823
# Epoch 2/2, discrimitor loss:0.9181 generator loss:1.0053
# Epoch 2/2, discrimitor loss:0.4970 generator loss:2.6071
# Epoch 2/2, discrimitor loss:0.5763 generator loss:1.8420
# Epoch 2/2, discrimitor loss:0.5854 generator loss:2.3430
# Epoch 2/2, discrimitor loss:0.5829 generator loss:1.9680
# Epoch 2/2, discrimitor loss:0.5994 generator loss:1.8591
# Epoch 2/2, discrimitor loss:0.6831 generator loss:1.3745
# Epoch 2/2, discrimitor loss:0.5567 generator loss:2.2874
# Epoch 2/2, discrimitor loss:0.7333 generator loss:2.6567
# Epoch 2/2, discrimitor loss:0.6117 generator loss:1.6565
# Epoch 2/2, discrimitor loss:0.5158 generator loss:2.2736
# Epoch 2/2, discrimitor loss:0.5249 generator loss:2.3811
# Epoch 2/2, discrimitor loss:0.5110 generator loss:2.2045
# Epoch 2/2, discrimitor loss:0.6129 generator loss:1.6774
# Epoch 2/2, discrimitor loss:0.5670 generator loss:1.9639
# Epoch 2/2, discrimitor loss:0.5010 generator loss:2.5857
# Epoch 2/2, discrimitor loss:0.8612 generator loss:3.5782
# Epoch 2/2, discrimitor loss:0.5668 generator loss:2.2834
# Epoch 2/2, discrimitor loss:0.6090 generator loss:1.6209
# Epoch 2/2, discrimitor loss:0.5450 generator loss:2.8533
# Epoch 2/2, discrimitor loss:1.0390 generator loss:3.2806
# Epoch 2/2, discrimitor loss:0.5741 generator loss:2.3357
# Epoch 2/2, discrimitor loss:0.5254 generator loss:2.1699
# Epoch 2/2, discrimitor loss:0.5069 generator loss:2.1212
# Epoch 2/2, discrimitor loss:0.7441 generator loss:3.8955
# Epoch 2/2, discrimitor loss:0.4986 generator loss:2.2567
# Epoch 2/2, discrimitor loss:0.5717 generator loss:1.8724
# Epoch 2/2, discrimitor loss:0.4949 generator loss:2.3299
# Epoch 2/2, discrimitor loss:0.6451 generator loss:1.5552
# Epoch 2/2, discrimitor loss:0.6468 generator loss:1.5661
# Epoch 2/2, discrimitor loss:0.5674 generator loss:2.0192
# Epoch 2/2, discrimitor loss:0.5919 generator loss:1.9938
# Epoch 2/2, discrimitor loss:0.5316 generator loss:2.1550
# Epoch 2/2, discrimitor loss:0.4760 generator loss:2.5690
# Epoch 2/2, discrimitor loss:0.5239 generator loss:2.0197
# Epoch 2/2, discrimitor loss:0.4951 generator loss:2.2914
# Epoch 2/2, discrimitor loss:0.6855 generator loss:1.4018
# Epoch 2/2, discrimitor loss:0.5020 generator loss:2.2183

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0002
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1, discrimitor loss:1.7005 generator loss:0.3551
# Epoch 1/1, discrimitor loss:0.5862 generator loss:2.2235
# Epoch 1/1, discrimitor loss:0.5822 generator loss:2.5714
# Epoch 1/1, discrimitor loss:0.5031 generator loss:3.0812
# Epoch 1/1, discrimitor loss:0.5327 generator loss:2.9097
# Epoch 1/1, discrimitor loss:0.4458 generator loss:3.2691
# Epoch 1/1, discrimitor loss:0.4495 generator loss:3.1500
# Epoch 1/1, discrimitor loss:0.4179 generator loss:3.4098
# Epoch 1/1, discrimitor loss:0.4149 generator loss:3.4153
# Epoch 1/1, discrimitor loss:0.3891 generator loss:3.8879
# Epoch 1/1, discrimitor loss:0.4030 generator loss:3.5674
# Epoch 1/1, discrimitor loss:0.4021 generator loss:3.5935
# Epoch 1/1, discrimitor loss:0.4880 generator loss:2.4086
# Epoch 1/1, discrimitor loss:0.4466 generator loss:3.1843
# Epoch 1/1, discrimitor loss:0.4895 generator loss:3.3561
# Epoch 1/1, discrimitor loss:0.5244 generator loss:2.4237
# Epoch 1/1, discrimitor loss:0.4951 generator loss:2.4450
# Epoch 1/1, discrimitor loss:0.5556 generator loss:2.2217
# Epoch 1/1, discrimitor loss:0.5324 generator loss:3.2903
# Epoch 1/1, discrimitor loss:0.5729 generator loss:3.2738
# Epoch 1/1, discrimitor loss:0.5466 generator loss:2.2270
# Epoch 1/1, discrimitor loss:0.5377 generator loss:2.1965
# Epoch 1/1, discrimitor loss:0.6184 generator loss:1.9744
# Epoch 1/1, discrimitor loss:0.5100 generator loss:2.5592
# Epoch 1/1, discrimitor loss:0.7725 generator loss:4.6920
# Epoch 1/1, discrimitor loss:0.5609 generator loss:2.2300
# Epoch 1/1, discrimitor loss:0.5805 generator loss:3.0557
# Epoch 1/1, discrimitor loss:0.8849 generator loss:3.0291
# Epoch 1/1, discrimitor loss:0.6567 generator loss:1.7168
# Epoch 1/1, discrimitor loss:0.7402 generator loss:1.3679
# Epoch 1/1, discrimitor loss:0.7418 generator loss:2.6349
# Epoch 1/1, discrimitor loss:0.7537 generator loss:1.3494
# Epoch 1/1, discrimitor loss:0.6050 generator loss:2.2125
# Epoch 1/1, discrimitor loss:0.6008 generator loss:2.5112
# Epoch 1/1, discrimitor loss:0.6786 generator loss:2.0579
# Epoch 1/1, discrimitor loss:0.8411 generator loss:1.1584
# Epoch 1/1, discrimitor loss:0.6195 generator loss:1.8332
# Epoch 1/1, discrimitor loss:0.6594 generator loss:1.8416
# Epoch 1/1, discrimitor loss:0.7313 generator loss:2.3641
# Epoch 1/1, discrimitor loss:0.7947 generator loss:2.5056
# Epoch 1/1, discrimitor loss:0.7628 generator loss:1.5393
# Epoch 1/1, discrimitor loss:0.7839 generator loss:1.8615
# Epoch 1/1, discrimitor loss:0.7089 generator loss:1.4600
# Epoch 1/1, discrimitor loss:0.7072 generator loss:1.7847
# Epoch 1/1, discrimitor loss:0.8395 generator loss:1.5204
# Epoch 1/1, discrimitor loss:0.7012 generator loss:1.9732
# Epoch 1/1, discrimitor loss:1.1165 generator loss:0.7216
# Epoch 1/1, discrimitor loss:0.7539 generator loss:1.9143
# Epoch 1/1, discrimitor loss:0.9715 generator loss:1.7395
# Epoch 1/1, discrimitor loss:1.0797 generator loss:2.4568
# Epoch 1/1, discrimitor loss:0.6782 generator loss:1.8633
# Epoch 1/1, discrimitor loss:0.7078 generator loss:2.1009
# Epoch 1/1, discrimitor loss:0.6482 generator loss:1.9369
# Epoch 1/1, discrimitor loss:0.7938 generator loss:1.3317
# Epoch 1/1, discrimitor loss:0.9304 generator loss:2.0488
# Epoch 1/1, discrimitor loss:0.8237 generator loss:1.5950
# Epoch 1/1, discrimitor loss:1.0833 generator loss:2.4660
# Epoch 1/1, discrimitor loss:1.1276 generator loss:1.0756
# Epoch 1/1, discrimitor loss:0.9852 generator loss:0.9619
# Epoch 1/1, discrimitor loss:0.9069 generator loss:1.6372
# Epoch 1/1, discrimitor loss:0.8559 generator loss:2.0653
# Epoch 1/1, discrimitor loss:0.7261 generator loss:1.6264
# Epoch 1/1, discrimitor loss:0.8690 generator loss:1.1524
# Epoch 1/1, discrimitor loss:0.8834 generator loss:1.0647
# Epoch 1/1, discrimitor loss:0.7982 generator loss:1.5206
# Epoch 1/1, discrimitor loss:0.9308 generator loss:1.4850
# Epoch 1/1, discrimitor loss:0.9382 generator loss:1.3061
# Epoch 1/1, discrimitor loss:0.8972 generator loss:1.4447
# Epoch 1/1, discrimitor loss:0.8563 generator loss:1.5318
# Epoch 1/1, discrimitor loss:0.9619 generator loss:1.0204
# Epoch 1/1, discrimitor loss:1.2406 generator loss:0.7028
# Epoch 1/1, discrimitor loss:0.9495 generator loss:1.2938
# Epoch 1/1, discrimitor loss:0.9695 generator loss:1.4692
# Epoch 1/1, discrimitor loss:0.9230 generator loss:1.2618
# Epoch 1/1, discrimitor loss:0.9374 generator loss:1.4842
# Epoch 1/1, discrimitor loss:1.0701 generator loss:1.8951
# Epoch 1/1, discrimitor loss:1.3930 generator loss:0.5376
# Epoch 1/1, discrimitor loss:0.8967 generator loss:1.3260
# Epoch 1/1, discrimitor loss:1.0302 generator loss:1.3431
# Epoch 1/1, discrimitor loss:0.9113 generator loss:1.7017
# Epoch 1/1, discrimitor loss:0.9731 generator loss:1.1822
# Epoch 1/1, discrimitor loss:1.0643 generator loss:0.9054
# Epoch 1/1, discrimitor loss:1.0175 generator loss:0.9003
# Epoch 1/1, discrimitor loss:0.9055 generator loss:1.1395
# Epoch 1/1, discrimitor loss:0.9878 generator loss:1.1725
# Epoch 1/1, discrimitor loss:0.8950 generator loss:1.3607
# Epoch 1/1, discrimitor loss:1.1728 generator loss:2.1020
# Epoch 1/1, discrimitor loss:0.9805 generator loss:1.6570
# Epoch 1/1, discrimitor loss:1.1119 generator loss:0.7821
# Epoch 1/1, discrimitor loss:1.0166 generator loss:1.0369
# Epoch 1/1, discrimitor loss:0.9883 generator loss:1.2274
# Epoch 1/1, discrimitor loss:0.8957 generator loss:1.2662
# Epoch 1/1, discrimitor loss:1.3109 generator loss:2.8321
# Epoch 1/1, discrimitor loss:0.9497 generator loss:1.4893
# Epoch 1/1, discrimitor loss:1.0241 generator loss:1.6540
# Epoch 1/1, discrimitor loss:0.8644 generator loss:1.4194
# Epoch 1/1, discrimitor loss:0.9591 generator loss:1.1744
# Epoch 1/1, discrimitor loss:1.0888 generator loss:0.9017
# Epoch 1/1, discrimitor loss:1.0270 generator loss:1.6634
# Epoch 1/1, discrimitor loss:0.8840 generator loss:1.3438
# Epoch 1/1, discrimitor loss:0.9311 generator loss:1.2935
# Epoch 1/1, discrimitor loss:1.0620 generator loss:1.8950
# Epoch 1/1, discrimitor loss:1.6612 generator loss:2.9210
# Epoch 1/1, discrimitor loss:0.9449 generator loss:1.3207
# Epoch 1/1, discrimitor loss:0.9593 generator loss:1.1219
# Epoch 1/1, discrimitor loss:0.9729 generator loss:1.6303
# Epoch 1/1, discrimitor loss:0.9777 generator loss:1.1751
# Epoch 1/1, discrimitor loss:0.9877 generator loss:1.1250
# Epoch 1/1, discrimitor loss:1.0267 generator loss:1.1212
# Epoch 1/1, discrimitor loss:0.9937 generator loss:0.9362
# Epoch 1/1, discrimitor loss:0.9742 generator loss:1.6683
# Epoch 1/1, discrimitor loss:0.9656 generator loss:1.4541
# Epoch 1/1, discrimitor loss:0.9052 generator loss:1.2644
# Epoch 1/1, discrimitor loss:0.9569 generator loss:1.4787
# Epoch 1/1, discrimitor loss:1.0054 generator loss:1.4211
# Epoch 1/1, discrimitor loss:0.9219 generator loss:1.1882
# Epoch 1/1, discrimitor loss:0.9633 generator loss:1.2066
# Epoch 1/1, discrimitor loss:0.9520 generator loss:1.3765
# Epoch 1/1, discrimitor loss:1.0338 generator loss:2.0045
# Epoch 1/1, discrimitor loss:0.9560 generator loss:1.4039
# Epoch 1/1, discrimitor loss:0.8793 generator loss:1.5267

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
