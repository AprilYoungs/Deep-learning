# %%
import numpy as np
import pandas as pd

# %%
df_n = pd.read_csv('new_york_city.csv')
df_w = pd.read_csv('washington.csv')
df_c = pd.read_csv('chicago.csv')

# %%
df_n.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     5688089  2017-06-11 14:55:05  2017-06-11 15:08:21            795
# 1     4096714  2017-05-11 15:30:11  2017-05-11 15:41:43            692
# 2     2173887  2017-03-29 13:26:26  2017-03-29 13:48:31           1325
# 3     3945638  2017-05-08 19:47:18  2017-05-08 19:59:01            703
# 4     6208972  2017-06-21 07:49:16  2017-06-21 07:54:46            329
#
#              Start Station             End Station   User Type  Gender  \
# 0  Suffolk St & Stanton St  W Broadway & Spring St  Subscriber    Male
# 1  Lexington Ave & E 63 St         1 Ave & E 78 St  Subscriber    Male
# 2        1 Pl & Clinton St    Henry St & Degraw St  Subscriber    Male
# 3    Barrow St & Hudson St         W 20 St & 8 Ave  Subscriber  Female
# 4          1 Ave & E 44 St         E 53 St & 3 Ave  Subscriber    Male
#
#    Birth Year
# 0      1998.0
# 1      1981.0
# 2      1987.0
# 3      1986.0
# 4      1992.0

# %%
df_w.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     1621326  2017-06-21 08:36:34  2017-06-21 08:44:43        489.066
# 1      482740  2017-03-11 10:40:00  2017-03-11 10:46:00        402.549
# 2     1330037  2017-05-30 01:02:59  2017-05-30 01:13:37        637.251
# 3      665458  2017-04-02 07:48:35  2017-04-02 08:19:03       1827.341
# 4     1481135  2017-06-10 08:36:28  2017-06-10 09:02:17       1549.427
#
#                                  Start Station                   End Station  \
# 0                         14th & Belmont St NW                15th & K St NW
# 1                   Yuma St & Tenley Circle NW  Connecticut Ave & Yuma St NW
# 2               17th St & Massachusetts Ave NW                 5th & K St NW
# 3             Constitution Ave & 2nd St NW/DOL    M St & Pennsylvania Ave NW
# 4  Henry Bacon Dr & Lincoln Memorial Circle NW         Maine Ave & 7th St SW
#
#     User Type
# 0  Subscriber
# 1  Subscriber
# 2  Subscriber
# ...

# %%
df_c.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     1423854  2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1      955915  2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2        9031  2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3      304487  2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4       45207  2017-01-17 14:53:07  2017-01-17 15:02:01            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year
# 0    Male      1992.0
# 1  Female      1992.0
# ...

# %%
df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 9 columns):
# Unnamed: 0       300000 non-null int64
# Start Time       300000 non-null object
# End Time         300000 non-null object
# Trip Duration    300000 non-null int64
# Start Station    300000 non-null object
# End Station      300000 non-null object
# User Type        300000 non-null object
# Gender           238948 non-null object
# Birth Year       238981 non-null float64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 20.6+ MB

# %%
df_c['Start Time'] = pd.to_datetime(df_c['Start Time'])
# Out:
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1           955915 2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2             9031 2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3           304487 2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4            45207 2017-01-17 14:53:07  2017-01-17 15:02:01            534
# 5          1473887 2017-06-26 09:01:20  2017-06-26 09:11:06            586
# 6           961916 2017-05-26 09:41:44  2017-05-26 09:46:25            281
# 7            65924 2017-01-21 14:28:38  2017-01-21 14:40:41            723
# 8           606841 2017-04-20 16:08:51  2017-04-20 16:20:20            689
# 9           135470 2017-02-06 18:00:47  2017-02-06 18:09:00            493
# 10          175805 2017-02-15 07:09:55  2017-02-15 07:14:56            301
# ...

# %%
date = df_c['Start Time'].iloc[2]

# %%
date
# Out:
# Timestamp('2017-01-04 08:27:49')

# %%
date.month
# Out:
# 1

# %%
df_c['date'] = pd.to_datetime(df_c['Start Time'])
df_c.head()
# Out:
#    Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0     1423854 2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1      955915 2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2        9031 2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3      304487 2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4       45207 2017-01-17 14:53:07  2017-01-17 15:02:01            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year                date
# 0    Male      1992.0 2017-06-23 15:09:32
# ...

# %%
df_c['month'] = df_c['date'].apply(lambda x: x.month)

# %%
df_c
# Out:
#         Unnamed: 0          Start Time             End Time  Trip Duration  \
# 0          1423854 2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1           955915 2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2             9031 2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3           304487 2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4            45207 2017-01-17 14:53:07  2017-01-17 15:02:01            534
# 5          1473887 2017-06-26 09:01:20  2017-06-26 09:11:06            586
# 6           961916 2017-05-26 09:41:44  2017-05-26 09:46:25            281
# 7            65924 2017-01-21 14:28:38  2017-01-21 14:40:41            723
# 8           606841 2017-04-20 16:08:51  2017-04-20 16:20:20            689
# 9           135470 2017-02-06 18:00:47  2017-02-06 18:09:00            493
# 10          175805 2017-02-15 07:09:55  2017-02-15 07:14:56            301
# ...

# %%
arr = [123,22]

# %%
df_c.dropna(inplace=True)

# %%
df = pd.read_csv('chicago.csv')
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (238948, 9)

# %%
df['date'] = pd.to_datetime(df['Start Time'])

# %%
df['month'] = df['date'].apply(lambda x: MONTH_DATA[x.month-1])

# %%
MONTH_DATA = ['january', 'february', 'march' ,'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december']

# %%
df.month.head()
# Out:
# 0       june
# 1        may
# 2    january
# 3      march
# 4    january
# Name: month, dtype: object

# %%
df['weekday'] = df['date'].apply(lambda x: x.weekday_name.lower())

# %%
df.shape
# Out:
# (27556, 11)

# %%
df.head()
# Out:
#     Unnamed: 0           Start Time             End Time  Trip Duration  \
# 9       135470  2017-02-06 18:00:47  2017-02-06 18:09:00            493
# 10      175805  2017-02-15 07:09:55  2017-02-15 07:14:56            301
# 22      161454  2017-02-12 15:24:29  2017-02-12 15:38:43            854
# 29      261757  2017-02-25 19:01:19  2017-02-25 19:08:10            411
# 36      165328  2017-02-13 14:17:25  2017-02-13 14:22:52            327
#
#                    Start Station                   End Station   User Type  \
# 9   Stetson Ave & South Water St  Clinton St & Washington Blvd  Subscriber
# 10          Broadway & Barry Ave      Wilton Ave & Belmont Ave  Subscriber
# 22    Clarendon Ave & Leland Ave   Lake Shore Dr & Belmont Ave  Subscriber
# 29      Halsted St & Dickens Ave   Halsted St & Wrightwood Ave  Subscriber
# 36      University Ave & 57th St         Kimbark Ave & 53rd St  Subscriber
#
#     Gender  Birth Year                date  month
# ...

# %%
date.weekday_name.lower()
# Out:
# 'wednesday'

# %%
df['weekday'] = df['date'].apply(lambda x: x.weekday_name.lower())

# %%
df.head()
# Out:
#     Unnamed: 0           Start Time             End Time  Trip Duration  \
# 9       135470  2017-02-06 18:00:47  2017-02-06 18:09:00            493
# 10      175805  2017-02-15 07:09:55  2017-02-15 07:14:56            301
# 22      161454  2017-02-12 15:24:29  2017-02-12 15:38:43            854
# 29      261757  2017-02-25 19:01:19  2017-02-25 19:08:10            411
# 36      165328  2017-02-13 14:17:25  2017-02-13 14:22:52            327
#
#                    Start Station                   End Station   User Type  \
# 9   Stetson Ave & South Water St  Clinton St & Washington Blvd  Subscriber
# 10          Broadway & Barry Ave      Wilton Ave & Belmont Ave  Subscriber
# 22    Clarendon Ave & Leland Ave   Lake Shore Dr & Belmont Ave  Subscriber
# 29      Halsted St & Dickens Ave   Halsted St & Wrightwood Ave  Subscriber
# 36      University Ave & 57th St         Kimbark Ave & 53rd St  Subscriber
#
#     Gender  Birth Year                date  month    weekday
# ...

# %%
df = df[df['weekday'] == 'wednesday']

# %%
df.shape
# Out:
# (4764, 12)

# %%
df.head()
# Out:
#      Unnamed: 0           Start Time             End Time  Trip Duration  \
# 10       175805  2017-02-15 07:09:55  2017-02-15 07:14:56            301
# 49       141745  2017-02-08 07:13:31  2017-02-08 07:16:17            166
# 55       239793  2017-02-22 07:51:44  2017-02-22 08:00:14            510
# 122      178170  2017-02-15 14:45:08  2017-02-15 14:59:11            843
# 227      241771  2017-02-22 11:29:11  2017-02-22 11:33:16            245
#
#                        Start Station                 End Station   User Type  \
# 10              Broadway & Barry Ave    Wilton Ave & Belmont Ave  Subscriber
# 49   Pine Grove Ave & Irving Park Rd  Clarendon Ave & Gordon Ter  Subscriber
# 55              Broadway & Barry Ave   Sedgwick St & Webster Ave  Subscriber
# 122          State St & Van Buren St        Clinton St & 18th St  Subscriber
# 227       Aberdeen St & Jackson Blvd         Morgan St & Polk St  Subscriber
#
#      Gender  Birth Year                date  month    weekday
# ...

# %%
# df.drop(['date','month','weekday'], axis=1, inplace=True)

# %%
df.head()
# Out:
#      Unnamed: 0           Start Time             End Time  Trip Duration  \
# 10       175805  2017-02-15 07:09:55  2017-02-15 07:14:56            301
# 49       141745  2017-02-08 07:13:31  2017-02-08 07:16:17            166
# 55       239793  2017-02-22 07:51:44  2017-02-22 08:00:14            510
# 122      178170  2017-02-15 14:45:08  2017-02-15 14:59:11            843
# 227      241771  2017-02-22 11:29:11  2017-02-22 11:33:16            245
#
#                        Start Station                 End Station   User Type  \
# 10              Broadway & Barry Ave    Wilton Ave & Belmont Ave  Subscriber
# 49   Pine Grove Ave & Irving Park Rd  Clarendon Ave & Gordon Ter  Subscriber
# 55              Broadway & Barry Ave   Sedgwick St & Webster Ave  Subscriber
# 122          State St & Van Buren St        Clinton St & 18th St  Subscriber
# 227       Aberdeen St & Jackson Blvd         Morgan St & Polk St  Subscriber
#
#      Gender  Birth Year
# 10   Female      1993.0
# ...

# %%
df.shape
# Out:
# (4764, 9)

# %%
df.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     1423854  2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1      955915  2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2        9031  2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3      304487  2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4       45207  2017-01-17 14:53:07  2017-01-17 15:02:01            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year                date    month    weekday
# ...

# %%
df.month.value_counts().idxmax()
# Out:
# 'june'

# %%
month_counts = df.month.value_counts()

# %%
month_counts
# Out:
# june        72468
# may         51034
# april       39835
# february    27556
# march       27251
# january     20804
# Name: month, dtype: int64

# %%
type(month_counts.idxmax())
# Out:
# str

# %%
df.weekday.value_counts().idxmax()
# Out:
# 'tuesday'

# %%
date.hour
# Out:
# 8

# %%
df['start_hour'] = df.date.apply(lambda x: x.hour)

# %%
df.start_hour
# Out:
# 0         15
# 1         18
# 2          8
# 3         13
# 4         14
# 5          9
# 6          9
# 8         16
# 9         18
# 10         7
# 11        15
# 12        16
# 13        15
# 14        19
# 15        22
# 16        13
# 17         8
# 18        21
# 20         6
# 21        12
# 22        15
# 23        19
# 24         9
# 25        20
# 26         9
# 27         7
# 28        18
# 29        19
# 30        16
# 32        17
#           ..
# 299957    15
# 299958    11
# 299959    21
# 299960    15
# 299961    16
# 299962    13
# 299964     8
# 299965    19
# 299967    19
# 299968    10
# 299969    15
# 299970    11
# 299971     9
# 299972     8
# 299974     7
# 299975    11
# 299976    18
# 299977    17
# 299978     8
# 299980     9
# 299982    17
# 299984    17
# 299985    17
# 299990    15
# 299991    19
# 299992    16
# 299994    17
# 299995    13
# 299997     9
# 299999    12
# Name: start_hour, Length: 238948, dtype: int64

# %%
common_start_hour = df.start_hour.value_counts().idxmax()

# %%
common_start_hour
# Out:
# 17

# %%
df['Start Station'].value_counts().idxmax()
# Out:
# 'Clinton St & Washington Blvd'

# %%
df['End Station'].value_counts().idxmax()
# Out:
# 'Clinton St & Washington Blvd'

# %%
df['S_E_Station'] = df['Start Station'] + ' to ' + df['End Station']

# %%
df['S_E_Station']
# Out:
# 0           Wood St & Hubbard St to Damen Ave & Chicago Ave
# 1         Theater on the Lake to Sheffield Ave & Wavelan...
# 2                 May St & Taylor St to Wood St & Taylor St
# 3         Christiana Ave & Lawrence Ave to St. Louis Ave...
# 4         Clark St & Randolph St to Desplaines St & Jack...
# 5         Clinton St & Washington Blvd to Canal St & Tay...
# 6             Ashland Ave & Lake St to Wood St & Hubbard St
# 8         Sedgwick St & Huron St to Halsted St & Blackha...
# 9         Stetson Ave & South Water St to Clinton St & W...
# 10         Broadway & Barry Ave to Wilton Ave & Belmont Ave
# 11        Southport Ave & Wellington Ave to Clark St & S...
# 12        Green St & Madison St to Ada St & Washington Blvd
# 13          Larrabee St & Kingsbury St to Clark St & Elm St
# 14        Canal St & Madison St to Racine Ave (May St) &...
# 15        Clark St & Armitage Ave to Sheffield Ave & Wri...
# 16           Ada St & Washington Blvd to Daley Center Plaza
# ...

# %%
df['S_E_Station'].value_counts().idxmax()
# Out:
# 'Canal St & Madison St to Michigan Ave & Washington St'

# %%
df['Trip Duration'].sum()
# Out:
# 167118035

# %%
df['Trip Duration'].mean()
# Out:
# 699.3908088789193

# %%
df.headad()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     1423854  2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1      955915  2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2        9031  2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3      304487  2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4       45207  2017-01-17 14:53:07  2017-01-17 15:02:01            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year                date    month    weekday  start_hour  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0           Start Time             End Time  Trip Duration  \
# 0     1423854  2017-06-23 15:09:32  2017-06-23 15:14:53            321
# 1      955915  2017-05-25 18:19:03  2017-05-25 18:45:53           1610
# 2        9031  2017-01-04 08:27:49  2017-01-04 08:34:45            416
# 3      304487  2017-03-06 13:49:38  2017-03-06 13:55:28            350
# 4       45207  2017-01-17 14:53:07  2017-01-17 15:02:01            534
#
#                    Start Station                   End Station   User Type  \
# 0           Wood St & Hubbard St       Damen Ave & Chicago Ave  Subscriber
# 1            Theater on the Lake  Sheffield Ave & Waveland Ave  Subscriber
# 2             May St & Taylor St           Wood St & Taylor St  Subscriber
# 3  Christiana Ave & Lawrence Ave  St. Louis Ave & Balmoral Ave  Subscriber
# 4         Clark St & Randolph St  Desplaines St & Jackson Blvd  Subscriber
#
#    Gender  Birth Year                date    month    weekday  start_hour  \
# ...

# %%
user_types = df['User Type'].value_counts()

# %%
user_types
# Out:
# Subscriber    238856
# Customer          91
# Dependent          1
# Name: User Type, dtype: int64

# %%
user_types.index
# Out:
# Index(['Subscriber', 'Customer', 'Dependent'], dtype='object')

# %%
user_types.loc['Subscriber']
# Out:
# 238856

# %%
for s in user_types.index:
    print('User type {} with a count of {}'.format(s, user_types.loc[s]))
# Out:
# User type Subscriber with a count of 238856
# User type Customer with a count of 91
# User type Dependent with a count of 1

# %%
gender_counts = df['Gender'].value_counts()

# %%
for s in gender_counts.index:
    print('Count of {} is {}'.format(s, gender_counts.loc[s]))
# Out:
# Count of Male is 181190
# Count of Female is 57758

# %%
df['Birth Year'].min()
# Out:
# 1899.0

# %%
df['Birth Year'].max()
# Out:
# 2016.0

# %%
df['Birth Year'].value_counts().idxmax()
# Out:
# 1989.0

# %%
df['Birth Year'].value_counts().count()
# Out:
# 79

# %%
's  '.strip()
# Out:
# 's'

# %%
' Ss'.lower()
# Out:
# ' ss'

# %%
df = pd.read_csv('chicago.csv')

# %%
df = df[df['Birth Year'] == 2020]

# %%
df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Start Time, End Time, Trip Duration, Start Station, End Station, User Type, Gender, Birth Year]
# Index: []

# %%
len(df)
# Out:
# 0
