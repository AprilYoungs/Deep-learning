# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [02:16, 230kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

# %%
t = 1e-5  #threshold probility

# %%
count_word = Counter(int_words)
length = len(int_words)

# %%
# frequency of words
f_w = [count_word[word]/length for word in int_words]

f_w = np.array(f_w)

# %%
# probility to keep words
p_k = (t/f_w)**(0.5)

# %%
# The final subsampled word list
train_words = []
chances = np.random.rand(len(int_words))

for i in range(len(int_words)):
    if p_k[i] > chances[i]:
        train_words.append(int_words[i])

# %%
len(train_words), len(int_words)
# Out:
# (4627752, 16680599)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1,high=window_size+1)
    left = max(0,idx-R)
    right = idx+R
    target_words = set(words[left:idx] + words[idx+1:right+1])

    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    with tf.name_scope('input'):
        inputs = tf.placeholder(dtype=tf.int32, shape=[None], name='inputs')
        labels = tf.placeholder(dtype=tf.int32, shape=[None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300 # Number of embedding features 
with train_graph.as_default():
    with tf.name_scope('embedding'):
        # create embedding weight matrix here
        embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding], minval=-1, maxval=1), name='embedding')
        # use tf.nn.embedding_lookup to get the hidden layer output
        embed = tf.nn.embedding_lookup(embedding, inputs, name='embed')

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    
    with tf.name_scope('negative_sampling'):
        # create softmax weight matrix here
        softmax_w = tf.Variable(tf.truncated_normal([n_vocab,n_embedding], stddev=0.1), name='softmax_w')
        # create softmax biases here
        softmax_b = tf.zeros([n_vocab], name='softmax_b')
        tf.summary.histogram('softmax_w',softmax_w)
        tf.summary.histogram('softmax_b',softmax_b)
    
        # Calculate the loss using negative sampling
        loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
        cost = tf.reduce_mean(loss)
        tf.summary.histogram('cost',cost)
        optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    with tf.name_scope('validation'):
        ## From Thushan Ganegedara's implementation
        valid_size = 16 # Random set of words to evaluate similarity on.
        valid_window = 100
        # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
        valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
        valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

        valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
        # We use the cosine distance:
        norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
        normalized_embedding = embedding / norm
        valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
        similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %% [markdown]
# <h1 style='color:#3aa'>Some mathematics that can be caculated,but I still can't understand that,this is the mystery of mathematics<h1>

# %% [markdown]
# ## use unix command this way

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
# !ls -lS
# Out:
# total 64440
# -rw-r--r--  1 April  staff  31344016 May 30 18:09 text8.zip
# -rw-r--r--  1 April  staff    822034 May 30 18:10 Skip-Gram_word2vec.ipynb
# -rw-r--r--  1 April  staff    813006 May 30 17:31 Skip-Grams-Solution.ipynb
# -rw-r--r--  1 April  staff      2194 May 30 17:31 utils.py
# -rw-r--r--  1 April  staff       863 May 30 17:31 requirements.txt
# drwxr-xr-x  9 April  staff       288 May 30 17:31 assets
# drwxr-xr-x  3 April  staff        96 May 30 17:32 __pycache__
# drwxr-xr-x  3 April  staff        96 May 30 17:31 data
# drwxr-xr-x  2 April  staff        64 May 30 18:11 checkpoints

# %% [markdown]
# ## recoder the graph

# %%
# Merges all summaries collected in the default graph.
with train_graph.as_default():
    summaries = tf.summary.merge_all()
writer = tf.summary.FileWriter('/tmp/word2vec',graph=train_graph)

# %%
summaries
# Out:
# <tf.Tensor 'Merge_1/MergeSummary:0' shape=() dtype=string>

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            summ,train_loss, _ = sess.run([summaries, cost, optimizer], feed_dict=feed)
            writer.add_summary(summ, iteration)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
                
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                run_option = tf.RunOptions(trace_level=tf.RunOptions.FULL_TRACE)
                metadata = tf.RunMetadata()
                summ = sess.run(summaries, 
                                feed_dict=feed, 
                                options=run_option,
                                run_metadata=metadata)
                writer.add_run_metadata(metadata, 'step%d' % iteration)
                writer.add_summary(summ, iteration)
                
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7708 0.9924 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7677 0.9822 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6888 0.9740 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7430 0.9590 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6836 0.9682 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6951 0.9458 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.7204 0.9524 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.7102 0.9579 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.6585 0.9570 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5915 0.9502 sec/batch
# Nearest to such: flatted, gingrich, marginally, inclusive, jokers, causation, concentrations, paraphrasing,
# Nearest to his: disjunction, it, castletown, gs, precaution, allegation, tley, kara,
# Nearest to would: depression, this, henares, crusade, gershon, shaftesbury, staunch, equivocal,
# Nearest to its: finance, prerequisite, agnetha, transportable, nurseries, underwent, nieve, denounced,
# Nearest to when: hilltop, deceptive, archivist, plainly, industrialization, prison, alkylation, physics,
# Nearest to may: squeezing, excommunicates, hbt, reinvented, write, hiiumaa, handicap, yugoslavia,
# Nearest to with: metastable, sidewinder, sin, convents, protests, policy, diaghilev, torr,
# Nearest to by: eradicating, homogeneous, czarist, kiyoshi, wilmut, typhon, procter, freight,
# Nearest to creation: lind, asn, applesoft, ellipsoids, typographical, vivekananda, cruciform, twister,
# Nearest to road: smog, ubu, fairgrounds, lipinski, besieges, phocoena, fingernails, needle,
# Nearest to cost: caruso, businessmen, cognate, mm, rescinded, affixes, ordering, porfirio,
# Nearest to accepted: tents, unofficial, protozoal, questionable, offeror, jaynes, distrust, simd,
# Nearest to brother: leet, noether, steamers, malted, trachea, upside, mahwah, reenactments,
# Nearest to joseph: addington, prevenient, geothermal, appeased, chthonic, chiuchow, gilbert, fouls,
# Nearest to notes: prohibiting, ventured, visualization, apok, bumin, evergreen, priapus, usha,
# Nearest to consists: superimposed, ova, philippines, catalyzed, m, transmutation, turf, quia,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.6897 0.9993 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.5848 0.9580 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.5102 0.9556 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.4250 0.9584 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.3621 0.9572 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2906 0.9544 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.2422 0.9496 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1784 0.9556 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.1049 0.9560 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0883 0.9534 sec/batch
# Nearest to such: concentrations, gingrich, organization, flatted, inclusive, uranus, rule, non,
# Nearest to his: it, disjunction, presumably, expand, strong, backyard, publishing, relatives,
# Nearest to would: this, depression, crusade, print, henares, domestic, character, gershon,
# Nearest to its: finance, system, prerequisite, underwent, ease, bought, action, handle,
# Nearest to when: plainly, deceptive, hilltop, physics, industrialization, masters, narrative, prison,
# Nearest to may: squeezing, write, features, excommunicates, yugoslavia, hiiumaa, cognitive, reinvented,
# Nearest to with: sin, policy, sidewinder, metastable, protests, convents, robust, sequence,
# Nearest to by: homogeneous, eradicating, dramatically, gained, czarist, wilmut, square, procter,
# Nearest to creation: typographical, lind, mitsotakis, regulate, asn, twister, mandeville, meanwhile,
# Nearest to road: smog, elevators, fairgrounds, mascarene, phocoena, besieges, heresy, vainly,
# Nearest to cost: cognate, businessmen, mm, caruso, ordering, notation, rescinded, statute,
# Nearest to accepted: unofficial, questionable, tents, simd, rotating, dis, distrust, offeror,
# Nearest to brother: leet, new, noether, upside, steamers, political, hydrozoa, europe,
# Nearest to joseph: gilbert, addington, appeased, chthonic, love, regional, surpassed, reliably,
# Nearest to notes: prohibiting, ventured, visualization, apok, evergreen, user, behind, taoism,
# Nearest to consists: superimposed, ova, m, philippines, catalyzed, both, indication, stressed,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.0337 0.9715 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.0171 0.9534 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9579 0.9552 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9476 0.9553 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.9412 0.9549 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8901 0.9602 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8693 0.9519 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8924 0.9607 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8633 0.9615 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8685 0.9658 sec/batch
# Nearest to such: concentrations, gingrich, provoke, inclusive, dispensing, flee, inter, causation,
# Nearest to his: allegation, disjunction, precaution, presumably, backyard, it, relatives, associate,
# Nearest to would: depression, this, shaftesbury, crusade, print, theft, henares, equivocal,
# Nearest to its: finance, prerequisite, system, underwent, hotels, ease, denounced, transportable,
# Nearest to when: hilltop, plainly, deceptive, industrialization, highways, archivist, masters, prison,
# Nearest to may: excommunicates, squeezing, blowing, diminished, features, amazing, reinvented, yugoslavia,
# Nearest to with: sidewinder, sin, robust, protests, policy, metastable, swallowing, convents,
# Nearest to by: homogeneous, eradicating, czarist, dramatically, gained, procter, typhon, kiyoshi,
# Nearest to creation: typographical, lind, mitsotakis, regulate, summarized, sprawling, asn, renn,
# Nearest to road: smog, fairgrounds, elevators, mascarene, evolving, needle, owed, phocoena,
# Nearest to cost: businessmen, caruso, cognate, rescinded, enlightened, mm, ordering, porfirio,
# Nearest to accepted: tents, questionable, unofficial, rotating, distrust, simd, blog, surrealism,
# Nearest to brother: leet, new, upside, noether, slump, political, europe, declassified,
# Nearest to joseph: geothermal, gilbert, fabian, appeased, addington, love, surpassed, chiuchow,
# Nearest to notes: prohibiting, ventured, visualization, user, apok, behind, puck, evergreen,
# Nearest to consists: superimposed, ova, m, philippines, indication, turf, catalyzed, stressed,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8784 0.9727 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8364 0.9573 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7785 0.9583 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7805 0.9600 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8022 0.9581 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7763 0.9629 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7878 0.9577 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.8002 0.9643 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7604 0.9684 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7360 0.9638 sec/batch
# Nearest to such: concentrations, batches, inclusive, gingrich, provoke, dispensing, jokers, flatted,
# Nearest to his: kara, allegation, precaution, publishing, disjunction, kasz, backyard, brunei,
# Nearest to would: depression, this, shaftesbury, crusade, equivocal, print, theft, gershon,
# Nearest to its: prerequisite, finance, system, hotels, underwent, interdependent, transportable, denounced,
# Nearest to when: hilltop, archivist, deceptive, industrialization, plainly, lav, prison, highways,
# Nearest to may: blowing, squeezing, excommunicates, diminished, amazing, features, reinvented, yugoslavia,
# Nearest to with: sidewinder, sin, metastable, robust, policy, eyed, protests, transliteration,
# Nearest to by: eradicating, czarist, homogeneous, dramatically, gained, procter, kiyoshi, wilmut,
# Nearest to creation: lind, mitsotakis, typographical, sprawling, asn, twister, regulate, cruciform,
# Nearest to road: smog, needle, mascarene, fairgrounds, elevators, fingernails, owed, halle,
# Nearest to cost: businessmen, caruso, rescinded, cognate, jihad, porfirio, mm, enlightened,
# Nearest to accepted: tents, questionable, distrust, unofficial, martians, rotating, jaynes, incarnation,
# Nearest to brother: leet, new, upside, noether, normalize, steamers, slump, political,
# Nearest to joseph: geothermal, gilbert, fabian, appeased, love, addington, volker, daughter,
# Nearest to notes: prohibiting, ventured, visualization, apok, user, puck, behind, usha,
# Nearest to consists: superimposed, ova, m, transmutation, turf, philippines, indication, outsource,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7251 0.9696 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7068 0.9533 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6597 0.9595 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6788 0.9597 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6780 0.9647 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6851 0.9751 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6536 0.6917 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5735 24.6139 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5363 1.0300 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5468 1.0408 sec/batch
# Nearest to such: batches, concentrations, inclusive, provoke, non, dispensing, governmental, gingrich,
# Nearest to his: kara, historian, achill, allegation, backyard, kasz, brunei, associate,
# Nearest to would: depression, this, shaftesbury, equivocal, pelagius, crusade, prepuce, theft,
# Nearest to its: prerequisite, system, finance, hotels, reproduce, transportable, interdependent, denounced,
# Nearest to when: hilltop, industrialization, archivist, deceptive, lav, plainly, greats, meinhof,
# Nearest to may: squeezing, blowing, excommunicates, reinvented, diminished, amazing, agra, cognitive,
# Nearest to with: sidewinder, sin, robust, parentheses, protests, metastable, revisit, unrecorded,
# Nearest to by: eradicating, czarist, homogeneous, procter, typhon, saarinen, kiyoshi, gained,
# Nearest to creation: mitsotakis, lind, typographical, asn, sprawling, summarized, twister, by,
# Nearest to road: smog, needle, mascarene, fairgrounds, elevators, fingernails, saiyan, lipinski,
# Nearest to cost: businessmen, rescinded, caruso, cognate, porfirio, enlightened, ordering, exceed,
# Nearest to accepted: tents, questionable, distrust, jaynes, incarnation, martians, rotating, simd,
# Nearest to brother: leet, noether, normalize, new, upside, stipulated, od, political,
# Nearest to joseph: gilbert, geothermal, fabian, appeased, volker, stein, prevenient, love,
# Nearest to notes: prohibiting, ventured, visualization, apok, behind, user, puck, usha,
# Nearest to consists: superimposed, ova, m, transmutation, intersputnik, turf, asheville, incline,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4992 1.0573 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5318 1.1247 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4469 1.3735 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5238 1.3220 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4924 1.3476 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4750 1.3811 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4595 1.3868 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3997 1.4531 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4240 1.4204 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4260 1.4192 sec/batch
# Nearest to such: inclusive, non, dispensing, governmental, batches, concentrations, gingrich, unfamiliar,
# Nearest to his: kara, backyard, historian, achill, allegation, relatives, ordaining, presumably,
# Nearest to would: depression, this, equivocal, shaftesbury, crusade, theft, print, privilege,
# Nearest to its: system, prerequisite, hotels, finance, transportable, reproduce, interdependent, barbarians,
# Nearest to when: hilltop, industrialization, deceptive, lav, meinhof, archivist, plainly, prison,
# Nearest to may: squeezing, blowing, reinvented, excommunicates, cognitive, diminished, amazing, chimpanzees,
# Nearest to with: robust, sidewinder, sin, hort, parentheses, cheap, turbulent, revisit,
# Nearest to by: eradicating, homogeneous, czarist, typhon, saarinen, wilmut, textual, kiyoshi,
# Nearest to creation: mitsotakis, typographical, asn, sprawling, lind, summarized, itself, kryptonians,
# Nearest to road: smog, needle, fingernails, built, besieges, saiyan, fairgrounds, mascarene,
# Nearest to cost: businessmen, rescinded, exceed, caruso, rollerball, mm, porfirio, same,
# Nearest to accepted: tents, questionable, distrust, incarnation, martians, jaynes, shun, rotating,
# Nearest to brother: leet, normalize, od, noether, new, wife, upside, barry,
# Nearest to joseph: gilbert, fabian, geothermal, appeased, divinity, daughter, volker, addington,
# Nearest to notes: prohibiting, ventured, visualization, apok, behind, user, usha, bumin,
# Nearest to consists: superimposed, ova, m, transmutation, intersputnik, both, turf, asheville,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4636 1.4920 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4325 1.4686 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4337 1.4865 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3821 1.4722 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3960 1.4848 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4446 1.5242 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3579 1.5027 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3900 1.4846 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4002 1.4935 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3658 1.5138 sec/batch
# Nearest to such: dispensing, refers, batches, inclusive, non, governmental, duodenum, gingrich,
# Nearest to his: backyard, relatives, historian, it, wlw, kara, allegation, impressed,
# Nearest to would: this, depression, equivocal, shaftesbury, gershon, theft, groundwork, staunch,
# Nearest to its: system, prerequisite, hotels, finance, transportable, reproduce, interdependent, coulomb,
# Nearest to when: hilltop, lav, deceptive, industrialization, meinhof, greats, plainly, remission,
# Nearest to may: squeezing, blowing, reinvented, diminished, chimpanzees, excommunicates, cognitive, coincidences,
# Nearest to with: sidewinder, robust, hort, sin, turbulent, unrecorded, parentheses, metastable,
# Nearest to by: eradicating, homogeneous, saarinen, czarist, typhon, kiyoshi, chronologically, artifice,
# Nearest to creation: mitsotakis, typographical, asn, sprawling, summarized, itself, lind, by,
# Nearest to road: smog, saiyan, fingernails, built, fairgrounds, needle, besieges, pitched,
# Nearest to cost: exceed, businessmen, rescinded, rollerball, caruso, pragmatism, divider, mm,
# Nearest to accepted: tents, questionable, distrust, incarnation, shun, jaynes, offeror, impure,
# Nearest to brother: leet, wife, normalize, upside, od, fond, barry, noether,
# Nearest to joseph: gilbert, fabian, stein, appeased, geothermal, divinity, volker, daughter,
# Nearest to notes: prohibiting, ventured, visualization, apok, user, usha, behind, bumin,
# Nearest to consists: superimposed, ova, m, stressed, turf, intersputnik, transmutation, both,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3814 1.5444 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3756 1.5434 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3743 1.5369 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3563 1.5408 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3949 1.5245 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3606 1.5179 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3845 1.6014 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3805 1.5565 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3413 1.5438 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3147 1.5332 sec/batch
# Nearest to such: dispensing, governmental, gingrich, inclusive, jokers, batches, refers, non,
# Nearest to his: fell, backyard, it, allegation, relatives, impressed, kara, historian,
# Nearest to would: this, depression, equivocal, shaftesbury, theft, privilege, pelagius, will,
# Nearest to its: prerequisite, finance, system, transportable, hotels, grander, yams, reproduce,
# Nearest to when: hilltop, lav, deceptive, industrialization, plainly, prison, meinhof, greats,
# Nearest to may: squeezing, diminished, blowing, yugoslavia, reinvented, january, excommunicates, sanctifying,
# Nearest to with: sidewinder, robust, transliteration, optimised, metastable, sin, turbulent, protests,
# Nearest to by: eradicating, homogeneous, saarinen, czarist, artifice, typhon, creation, textual,
# Nearest to creation: mitsotakis, sprawling, by, typographical, asn, itself, summarized, lind,
# Nearest to road: built, saiyan, smog, fairgrounds, fingernails, besieges, needle, pitched,
# Nearest to cost: exceed, businessmen, divider, rollerball, caruso, rescinded, microprocessors, profits,
# Nearest to accepted: tents, distrust, questionable, incarnation, jaynes, shun, martians, impure,
# Nearest to brother: wife, leet, upside, fond, normalize, lubin, stipulated, tunis,
# Nearest to joseph: fabian, gilbert, appeased, stein, divinity, addington, volker, daughter,
# Nearest to notes: prohibiting, ventured, visualization, apok, user, usha, behind, taoism,
# Nearest to consists: superimposed, ova, both, turf, ilium, transmutation, ethologists, m,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3573 1.5661 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2854 1.5737 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3934 1.5770 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3705 1.5954 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3944 1.5798 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2781 1.5106 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3335 1.5598 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3574 1.5554 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2219 1.5733 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3349 1.5337 sec/batch
# Nearest to such: dispensing, governmental, inclusive, refers, jokers, gingrich, batches, sht,
# Nearest to his: fell, backyard, it, impressed, allegation, hawks, strong, ordaining,
# Nearest to would: this, depression, equivocal, shaftesbury, theft, privilege, staunch, crusade,
# Nearest to its: prerequisite, system, reproduce, hotels, barbarians, transportable, finance, violate,
# Nearest to when: hilltop, lav, industrialization, deceptive, plainly, prison, meinhof, greats,
# Nearest to may: squeezing, yugoslavia, january, blowing, diminished, angiosperm, sanctifying, reinvented,
# Nearest to with: robust, sidewinder, turbulent, optimised, hort, sin, metastable, protests,
# Nearest to by: eradicating, homogeneous, saarinen, czarist, chronologically, typhon, dramatically, finances,
# Nearest to creation: mitsotakis, sprawling, asn, by, typographical, lind, summarized, itself,
# Nearest to road: smog, built, saiyan, fairgrounds, needle, besieges, pitched, fingernails,
# Nearest to cost: exceed, businessmen, microprocessors, rollerball, divider, rescinded, caruso, pragmatism,
# Nearest to accepted: tents, questionable, distrust, jaynes, incarnation, impure, shun, deriving,
# Nearest to brother: wife, upside, leet, barry, stipulated, fond, normalize, lubin,
# Nearest to joseph: fabian, gilbert, volker, appeased, stein, prevenient, divinity, addington,
# Nearest to notes: prohibiting, ventured, visualization, apok, usha, taoism, behind, user,
# Nearest to consists: superimposed, ova, babbling, independents, m, stressed, ilium, intersputnik,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3025 1.5570 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2876 1.5524 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3366 0.7009 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2443 1.5647 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2027 1.5516 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2111 1.5486 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2262 1.5825 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1995 1.5647 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2281 1.5577 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1424 1.5812 sec/batch
# Nearest to such: dispensing, governmental, gingrich, refers, inclusive, jokers, sht, microlensing,
# Nearest to his: fell, backyard, achill, ordaining, impressed, it, him, animatronic,
# Nearest to would: this, depression, equivocal, shaftesbury, theft, prepuce, will, pelagius,
# Nearest to its: prerequisite, system, is, hotels, latium, oint, barbarians, incognita,
# Nearest to when: hilltop, prison, lav, plainly, archivist, industrialization, deceptive, greats,
# Nearest to may: squeezing, blowing, yugoslavia, january, diminished, angiosperm, reinvented, iberians,
# Nearest to with: sidewinder, robust, turbulent, outboard, optimised, sin, olympians, transliteration,
# Nearest to by: czarist, eradicating, saarinen, homogeneous, typhon, square, creation, chronologically,
# Nearest to creation: mitsotakis, sprawling, by, asn, typographical, itself, summarized, validity,
# Nearest to road: smog, built, saiyan, needle, fairgrounds, besieges, high, fingernails,
# Nearest to cost: businessmen, exceed, microprocessors, divider, rescinded, rollerball, profits, caruso,
# Nearest to accepted: tents, questionable, jaynes, distrust, deriving, incarnation, shun, impure,
# Nearest to brother: wife, upside, leet, lubin, stipulated, fond, normalize, corpse,
# Nearest to joseph: fabian, gilbert, volker, stein, appeased, prevenient, addington, divinity,
# Nearest to notes: prohibiting, ventured, apok, visualization, taoism, usha, louisa, bumin,
# Nearest to consists: superimposed, ova, ethologists, stressed, independents, both, ilium, m,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2102 1.6066 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1873 1.5389 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2276 1.5417 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1150 1.5787 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1389 1.5636 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1659 1.5667 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1617 1.5926 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1458 1.5496 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2000 1.5739 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1567 1.5670 sec/batch
# Nearest to such: dispensing, governmental, gingrich, inclusive, refers, sht, iridium, non,
# Nearest to his: fell, backyard, impressed, wlw, it, ordaining, achill, him,
# Nearest to would: this, depression, equivocal, causes, shaftesbury, staunch, will, theft,
# Nearest to its: prerequisite, system, is, hotels, violate, interdependent, reproduce, autonomously,
# Nearest to when: plainly, lav, remission, hilltop, prison, industrialization, deceptive, archivist,
# Nearest to may: squeezing, yugoslavia, blowing, january, iberians, diminished, angiosperm, chimpanzees,
# Nearest to with: sidewinder, robust, turbulent, outboard, sin, metastable, threes, optimised,
# Nearest to by: saarinen, homogeneous, czarist, eradicating, square, typhon, dommel, chronologically,
# Nearest to creation: mitsotakis, typographical, sprawling, itself, asn, summarized, validity, profound,
# Nearest to road: built, smog, saiyan, fairgrounds, needle, roads, fingernails, gustavus,
# Nearest to cost: businessmen, microprocessors, exceed, divider, rescinded, rollerball, profits, caruso,
# Nearest to accepted: tents, questionable, jaynes, impure, distrust, incarnation, deriving, offeror,
# Nearest to brother: wife, leet, upside, fond, normalize, lubin, stipulated, completed,
# Nearest to joseph: fabian, appeased, volker, gilbert, addington, prevenient, divinity, stein,
# Nearest to notes: prohibiting, ventured, apok, visualization, taoism, usha, louisa, bumin,
# Nearest to consists: superimposed, ova, both, stressed, ilium, ethologists, independents, indication,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1517 1.6084 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2243 1.5813 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1630 1.5801 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1296 1.5675 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1647 1.5368 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2043 1.5930 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2072 1.5485 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1423 1.5493 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1150 1.5223 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1640 1.5552 sec/batch
# Nearest to such: dispensing, governmental, sht, iridium, gingrich, inclusive, derailleur, flatted,
# Nearest to his: fell, it, backyard, wlw, ordaining, animatronic, impressed, achill,
# Nearest to would: this, depression, equivocal, will, print, theft, shaftesbury, causes,
# Nearest to its: prerequisite, system, finance, violate, is, hotels, latium, reproduce,
# Nearest to when: plainly, hilltop, remission, lav, archivist, prison, industrialization, escorts,
# Nearest to may: squeezing, iberians, january, blowing, yugoslavia, diminished, sanctifying, assistive,
# Nearest to with: sidewinder, robust, sin, turbulent, outboard, olympians, metastable, protests,
# Nearest to by: saarinen, czarist, homogeneous, eradicating, typhon, chronologically, procter, square,
# Nearest to creation: mitsotakis, sprawling, itself, typographical, validity, profound, asn, summarized,
# Nearest to road: smog, built, fairgrounds, saiyan, needle, besieges, roads, gustavus,
# Nearest to cost: businessmen, microprocessors, exceed, profits, rollerball, divider, caruso, rescinded,
# Nearest to accepted: tents, questionable, impure, jaynes, deriving, offeror, distrust, shun,
# Nearest to brother: wife, upside, leet, fond, normalize, stipulated, pregnant, completed,
# Nearest to joseph: fabian, appeased, gilbert, addington, volker, prevenient, milford, stein,
# Nearest to notes: prohibiting, ventured, visualization, apok, taoism, ricci, louisa, usha,
# Nearest to consists: superimposed, ova, independents, both, stressed, ilium, dial, incline,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1774 1.5714 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1341 1.5651 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1680 1.5288 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1643 1.5666 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1458 1.5558 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1093 1.5558 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1630 1.5627 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1477 1.5431 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1823 1.5532 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1747 1.5524 sec/batch
# Nearest to such: governmental, dispensing, inclusive, gingrich, sht, wikipedians, iridium, cinemas,
# Nearest to his: fell, impressed, it, him, wlw, ordaining, backyard, legate,
# Nearest to would: this, depression, shaftesbury, will, dispossessed, equivocal, causes, theft,
# Nearest to its: prerequisite, is, violate, interdependent, mair, reproduce, denounced, system,
# Nearest to when: hilltop, plainly, lav, prison, archivist, remission, bronislaw, offender,
# Nearest to may: squeezing, january, yugoslavia, iberians, diminished, sanctifying, rigidly, angiosperm,
# Nearest to with: sidewinder, robust, sin, turbulent, scivias, receiving, olympians, protests,
# Nearest to by: czarist, eradicating, saarinen, homogeneous, in, typhon, procter, artifice,
# Nearest to creation: mitsotakis, sprawling, itself, asn, validity, typographical, mandeville, deception,
# Nearest to road: smog, built, fairgrounds, saiyan, gustavus, besieges, lipinski, pilsner,
# Nearest to cost: businessmen, microprocessors, exceed, divider, profits, rollerball, caruso, rescinded,
# Nearest to accepted: tents, impure, questionable, jaynes, incarnation, coro, deriving, distrust,
# Nearest to brother: wife, upside, leet, completed, normalize, stipulated, fond, pregnant,
# Nearest to joseph: fabian, milford, appeased, addington, gilbert, volker, prevenient, stein,
# Nearest to notes: prohibiting, ventured, apok, ricci, taoism, louisa, visualization, usha,
# Nearest to consists: superimposed, ova, independents, ilium, both, stressed, incline, maple,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2160 1.5484 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1494 1.5791 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1371 1.5612 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1336 1.5686 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0117 1.5777 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1222 1.5905 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1135 1.5711 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1300 1.5456 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1624 0.3042 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1049 1.5681 sec/batch
# Nearest to such: governmental, dispensing, inclusive, sht, iridium, gingrich, wikipedians, cinemas,
# Nearest to his: fell, him, impressed, it, returned, ordaining, legate, he,
# Nearest to would: this, depression, shaftesbury, will, causes, equivocal, invoke, snatch,
# Nearest to its: is, prerequisite, mair, incognita, hotels, latium, interdependent, reproduce,
# Nearest to when: plainly, lav, hilltop, remission, archivist, offender, prison, greats,
# Nearest to may: squeezing, january, iberians, yugoslavia, blowing, diminished, sanctifying, angiosperm,
# Nearest to with: robust, sidewinder, outboard, turbulent, some, colloquialism, scivias, sin,
# Nearest to by: czarist, saarinen, homogeneous, eradicating, typhon, chronologically, in, dramatically,
# Nearest to creation: mitsotakis, sprawling, itself, asn, by, typographical, deception, seaboard,
# Nearest to road: smog, built, fairgrounds, gustavus, saiyan, besieges, pilsner, roads,
# Nearest to cost: microprocessors, businessmen, exceed, divider, profits, rollerball, rescinded, brushes,
# Nearest to accepted: tents, impure, questionable, coro, jaynes, offeror, incarnation, deriving,
# Nearest to brother: wife, upside, leet, completed, normalize, stipulated, corpse, pregnant,
# Nearest to joseph: fabian, milford, prevenient, appeased, addington, volker, gilbert, stein,
# Nearest to notes: prohibiting, ventured, apok, visualization, taoism, louisa, ricci, priapus,
# Nearest to consists: superimposed, ova, independents, members, dial, ilium, both, legislative,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0544 1.5694 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0182 1.5585 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0402 1.5625 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0454 1.5442 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0444 1.5623 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9895 1.5842 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0632 1.5574 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0783 1.5257 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0841 1.5393 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0003 1.5383 sec/batch
# Nearest to such: governmental, dispensing, inclusive, gingrich, sht, iridium, wikipedians, non,
# Nearest to his: fell, him, impressed, he, returned, it, legate, dylan,
# Nearest to would: this, depression, will, causes, equivocal, print, dispossessed, shaftesbury,
# Nearest to its: is, prerequisite, hotels, incognita, mair, system, latium, oint,
# Nearest to when: lav, hilltop, remission, plainly, archivist, prison, industrialization, offender,
# Nearest to may: squeezing, january, iberians, yugoslavia, blowing, angiosperm, sanctifying, rigidly,
# Nearest to with: sidewinder, robust, colloquialism, outboard, some, sin, oscillations, scivias,
# Nearest to by: czarist, saarinen, homogeneous, in, dramatically, typhon, eradicating, futurists,
# Nearest to creation: mitsotakis, sprawling, itself, by, agnostics, asn, deception, profound,
# Nearest to road: smog, built, roads, fairgrounds, gustavus, pilsner, saiyan, besieges,
# Nearest to cost: businessmen, microprocessors, exceed, profits, divider, rollerball, brushes, rescinded,
# Nearest to accepted: tents, questionable, impure, jaynes, offeror, coro, deriving, incarnation,
# Nearest to brother: wife, leet, upside, completed, normalize, corpse, genoa, wane,
# Nearest to joseph: fabian, milford, appeased, addington, prevenient, gilbert, volker, midwives,
# Nearest to notes: prohibiting, ventured, apok, louisa, visualization, taoism, ricci, bumin,
# Nearest to consists: superimposed, members, independents, ova, legislative, ilium, dial, legislature,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9854 1.5770 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0172 1.5685 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9724 1.5564 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0338 1.6073 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0346 1.5801 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0245 1.5580 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0664 1.5777 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0786 1.5597 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0165 1.5738 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0411 1.5429 sec/batch
# Nearest to such: governmental, dispensing, inclusive, vp, non, sht, wikipedians, gingrich,
# Nearest to his: fell, him, career, animatronic, impressed, he, legate, backyard,
# Nearest to would: this, depression, will, causes, equivocal, staunch, print, displeased,
# Nearest to its: is, hotels, prerequisite, mair, incognita, system, interdependent, creation,
# Nearest to when: lav, hilltop, plainly, remission, archivist, malfunction, pearly, greats,
# Nearest to may: squeezing, iberians, january, blowing, yugoslavia, angiosperm, diminished, chimpanzees,
# Nearest to with: robust, sidewinder, colloquialism, some, sin, receiving, optimised, a,
# Nearest to by: czarist, saarinen, homogeneous, dramatically, in, eradicating, chronologically, edition,
# Nearest to creation: sprawling, mitsotakis, itself, asn, deception, agnostics, its, summarized,
# Nearest to road: built, smog, fairgrounds, roads, gustavus, saiyan, pilsner, besieges,
# Nearest to cost: businessmen, microprocessors, profits, exceed, divider, rollerball, brushes, rescinded,
# Nearest to accepted: tents, impure, questionable, jaynes, offeror, incarnation, andries, deriving,
# Nearest to brother: wife, leet, upside, completed, genoa, natasha, stipulated, corpse,
# Nearest to joseph: appeased, milford, prevenient, addington, fabian, gilbert, volker, midwives,
# Nearest to notes: prohibiting, taoism, ventured, apok, visualization, louisa, ricci, bumin,
# Nearest to consists: superimposed, independents, ova, members, legislative, dial, both, ilium,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0161 1.5774 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0478 1.5880 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0594 1.5625 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0214 1.5609 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0562 1.5490 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0570 1.5949 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0445 1.5568 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0308 1.5655 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0550 1.5773 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0429 1.5898 sec/batch
# Nearest to such: dispensing, governmental, inclusive, gingrich, sht, cinemas, vp, wikipedians,
# Nearest to his: fell, him, legate, he, career, returned, impressed, animatronic,
# Nearest to would: this, depression, print, displeased, dispossessed, will, causes, shaftesbury,
# Nearest to its: is, prerequisite, the, sek, hotels, mair, incognita, creation,
# Nearest to when: plainly, remission, hilltop, archivist, lav, industrialization, offender, passover,
# Nearest to may: iberians, squeezing, january, yugoslavia, sanctifying, blowing, diminished, angiosperm,
# Nearest to with: robust, sidewinder, turbulent, some, a, colloquialism, receiving, scivias,
# Nearest to by: saarinen, czarist, eradicating, in, the, homogeneous, dramatically, chronologically,
# Nearest to creation: mitsotakis, sprawling, itself, seaboard, irresponsible, deception, agnostics, its,
# Nearest to road: smog, built, gustavus, roads, fairgrounds, besieges, saiyan, pilsner,
# Nearest to cost: businessmen, microprocessors, profits, exceed, divider, rollerball, brushes, maintain,
# Nearest to accepted: tents, questionable, impure, andries, incarnation, deriving, jaynes, issuing,
# Nearest to brother: wife, upside, completed, leet, genoa, stipulated, elcano, daughter,
# Nearest to joseph: milford, appeased, fabian, addington, prevenient, volker, gilbert, montesquieu,
# Nearest to notes: prohibiting, louisa, ventured, apok, taoism, ricci, visualization, attribute,
# Nearest to consists: superimposed, independents, ova, members, dial, legislative, consecrate, ilium,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0527 1.5853 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9835 1.5555 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0167 1.5664 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0525 1.5849 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0676 1.5871 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1048 1.5403 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1308 1.5278 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0053 1.6035 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0198 1.5607 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0348 1.5476 sec/batch
# Nearest to such: governmental, dispensing, inclusive, wikipedians, sht, non, rule, vp,
# Nearest to his: fell, he, him, career, impressed, dylan, returned, legate,
# Nearest to would: this, will, depression, displeased, causes, equivocal, dispossessed, shaftesbury,
# Nearest to its: is, prerequisite, mair, incognita, violate, the, interdependent, latium,
# Nearest to when: hilltop, archivist, lav, offender, plainly, remission, greats, ashurbanipal,
# Nearest to may: january, iberians, squeezing, sanctifying, yugoslavia, diminished, angiosperm, blowing,
# Nearest to with: robust, a, sidewinder, some, colloquialism, turbulent, receiving, sin,
# Nearest to by: czarist, saarinen, homogeneous, dramatically, chronologically, in, eradicating, edition,
# Nearest to creation: sprawling, mitsotakis, itself, deception, its, seaboard, asn, irresponsible,
# Nearest to road: smog, built, roads, gustavus, transportation, fairgrounds, lipinski, streets,
# Nearest to cost: businessmen, microprocessors, exceed, divider, profits, rollerball, brushes, rescinded,
# Nearest to accepted: tents, andries, impure, questionable, jaynes, coro, incarnation, quatrain,
# Nearest to brother: wife, completed, stipulated, leet, upside, genoa, wane, normalize,
# Nearest to joseph: milford, fabian, prevenient, appeased, volker, addington, montesquieu, gilbert,
# Nearest to notes: prohibiting, ventured, taoism, apok, louisa, ricci, visualization, attribute,
# Nearest to consists: superimposed, independents, ova, members, consisting, legislative, dial, ilium,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9623 1.5952 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9977 1.5391 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0487 1.5758 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0276 1.5647 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0672 1.5862 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0256 1.4511 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9899 1.5886 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9480 1.5643 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9992 1.5782 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9334 1.5394 sec/batch
# Nearest to such: governmental, dispensing, inclusive, non, wikipedians, sht, vp, have,
# Nearest to his: he, fell, him, returned, career, legate, impressed, was,
# Nearest to would: this, will, causes, displeased, print, equivocal, shaftesbury, dispossessed,
# Nearest to its: is, prerequisite, incognita, mair, the, hotels, creation, sek,
# Nearest to when: hilltop, plainly, lav, remission, archivist, prison, offender, greats,
# Nearest to may: iberians, january, squeezing, angiosperm, sanctifying, yugoslavia, diminished, contrition,
# Nearest to with: robust, a, sidewinder, outboard, some, colloquialism, olympians, turbulent,
# Nearest to by: czarist, saarinen, homogeneous, the, in, of, edition, chronologically,
# Nearest to creation: mitsotakis, sprawling, its, itself, deception, asn, seaboard, irresponsible,
# Nearest to road: smog, gustavus, built, roads, besieges, transportation, fairgrounds, lipinski,
# Nearest to cost: businessmen, microprocessors, divider, exceed, profits, brushes, rollerball, rescinded,
# Nearest to accepted: tents, andries, questionable, impure, incarnation, jaynes, coro, deriving,
# Nearest to brother: wife, stipulated, completed, genoa, wane, upside, daughter, leet,
# Nearest to joseph: milford, prevenient, fabian, addington, appeased, gilbert, stein, volker,
# Nearest to notes: prohibiting, ventured, louisa, apok, taoism, ricci, visualization, attribute,
# Nearest to consists: superimposed, independents, ova, members, consisting, dial, ilium, consecrate,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9814 1.6022 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8964 1.5409 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9812 1.5687 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9930 1.5868 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9968 1.5758 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9755 1.5418 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8965 1.5680 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9318 1.5280 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9113 1.5659 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9492 1.5557 sec/batch
# Nearest to such: governmental, dispensing, inclusive, have, non, are, gingrich, iridium,
# Nearest to his: fell, he, career, him, legate, returned, impressed, animatronic,
# Nearest to would: this, will, causes, print, displeased, equivocal, dispossessed, depression,
# Nearest to its: is, mair, incognita, prerequisite, hotels, the, creation, sek,
# Nearest to when: remission, archivist, plainly, lav, hilltop, malfunction, greats, pearly,
# Nearest to may: iberians, squeezing, january, yugoslavia, sanctifying, angiosperm, diminished, contrition,
# Nearest to with: sidewinder, a, robust, to, some, turbulent, receiving, colloquialism,
# Nearest to by: czarist, saarinen, the, homogeneous, in, of, eradicating, dramatically,
# Nearest to creation: mitsotakis, sprawling, itself, seaboard, its, asn, deception, enumerative,
# Nearest to road: smog, built, gustavus, roads, transportation, fairgrounds, carpets, streets,
# Nearest to cost: businessmen, microprocessors, divider, exceed, brushes, profits, rollerball, rescinded,
# Nearest to accepted: tents, andries, questionable, incarnation, impure, deriving, jaynes, martians,
# Nearest to brother: wife, completed, genoa, leet, wane, upside, stipulated, allori,
# Nearest to joseph: prevenient, milford, fabian, enoch, appeased, addington, vaishnavite, terraced,
# Nearest to notes: prohibiting, apok, louisa, ventured, taoism, visualization, ricci, afips,
# Nearest to consists: superimposed, independents, members, consisting, legislative, ova, balances, consecrate,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9653 1.5980 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9538 1.5229 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9472 1.5361 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9708 1.5258 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0138 1.5476 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9173 1.5666 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9787 1.5687 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9632 1.5290 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9446 1.5172 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9680 1.5214 sec/batch
# Nearest to such: governmental, dispensing, have, inclusive, vp, non, liberals, gingrich,
# Nearest to his: career, he, him, fell, animatronic, legate, impressed, advice,
# Nearest to would: this, will, causes, displeased, print, dispossessed, equivocal, teague,
# Nearest to its: is, the, mair, incognita, prerequisite, sek, hotels, interdependent,
# Nearest to when: archivist, remission, plainly, hilltop, finalized, offender, lav, malfunction,
# Nearest to may: iberians, squeezing, january, sanctifying, angiosperm, diminished, contrition, yugoslavia,
# Nearest to with: sidewinder, a, scivias, to, robust, turbulent, receiving, some,
# Nearest to by: czarist, the, in, saarinen, homogeneous, of, eradicating, edition,
# Nearest to creation: mitsotakis, itself, sprawling, seaboard, deception, asn, its, cavendish,
# Nearest to road: smog, gustavus, built, lipinski, fairgrounds, halle, transportation, besieges,
# Nearest to cost: microprocessors, businessmen, profits, divider, brushes, exceed, rollerball, rescinded,
# Nearest to accepted: tents, andries, questionable, quatrain, incarnation, impure, jaynes, deriving,
# Nearest to brother: wife, completed, genoa, daughter, stipulated, upside, leet, allori,
# Nearest to joseph: milford, prevenient, fabian, addington, enoch, stein, murray, volker,
# Nearest to notes: prohibiting, ventured, louisa, apok, taoism, ricci, visualization, bumin,
# Nearest to consists: superimposed, independents, members, consisting, ova, legislative, balances, consecrate,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9780 1.5890 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9827 1.5519 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9324 1.5508 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9696 1.5427 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9682 1.5690 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9876 1.5570 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9472 1.5829 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9186 1.5513 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9400 1.5129 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0067 1.5354 sec/batch
# Nearest to such: governmental, dispensing, have, inclusive, vp, are, non, iridium,
# Nearest to his: he, him, fell, career, legate, impressed, returned, animatronic,
# Nearest to would: this, will, causes, print, displeased, depression, dispossessed, teague,
# Nearest to its: is, the, sek, incognita, prerequisite, aimed, creation, finance,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8124 0.9692 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8258 0.9431 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8609 0.9555 sec/batch
# Nearest to such: most, have, are, with, governmental, often, other, for,
# Nearest to his: he, him, fell, career, animatronic, acting, bilbo, impressed,
# Nearest to would: this, will, equivocal, print, causes, metabolised, wanted, get,
# Nearest to its: the, is, it, of, a, part, in, mair,
# Nearest to when: to, the, finalized, stalls, after, was, be, as,
# Nearest to may: iberians, is, features, contrition, diminished, not, january, arkady,
# Nearest to with: to, a, in, such, of, from, it, three,
# Nearest to by: the, of, in, and, from, s, as, whose,
# Nearest to creation: itself, seaboard, manning, icosahedral, geographers, seated, inmate, footing,
# Nearest to road: streets, pilsner, smog, roads, green, lipinski, rebar, gustavus,
# Nearest to cost: microprocessors, brushes, sleeper, chieftains, specialization, profits, divider, industry,
# Nearest to accepted: andries, questionable, incarnation, quatrain, martians, incomplete, biologist, coro,
# Nearest to brother: completed, phaedra, private, wife, intern, cmyk, elcano, vba,
# Nearest to joseph: catharine, terraced, enoch, milford, ntc, prevenient, theorizes, addington,
# Nearest to notes: note, ventured, apok, publications, prohibiting, elongation, louisa, mohr,
# Nearest to consists: consisting, superimposed, consecrate, balances, branch, independents, all, ilium,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7839 1.0605 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8135 0.9359 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8188 0.9590 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8278 1.0042 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8375 0.9285 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8379 0.9193 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8494 0.9198 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8102 0.9281 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8562 0.9625 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8382 0.9794 sec/batch
# Nearest to such: most, have, are, with, governmental, often, dispensing, openoffice,
# Nearest to his: he, him, fell, career, bilbo, died, was, father,
# Nearest to would: this, will, print, wanted, equivocal, some, delegate, sontag,
# Nearest to its: the, is, it, of, part, a, in, both,
# Nearest to when: finalized, to, the, stalls, after, its, hippodrome, dmg,
# Nearest to may: iberians, features, diminished, contrition, january, arkady, is, calorie,
# Nearest to with: to, a, in, such, of, some, it, scivias,
# Nearest to by: the, of, in, and, from, whose, s, first,
# Nearest to creation: itself, seaboard, icosahedral, inmate, untethered, manning, geographers, colonialists,
# Nearest to road: streets, lipinski, smog, pilsner, rebar, gustavus, roads, carpets,
# Nearest to cost: microprocessors, brushes, industry, specialization, sleeper, chieftains, profits, affixes,
# Nearest to accepted: incarnation, quatrain, andries, compulsory, informed, questionable, indentation, ordinary,
# Nearest to brother: phaedra, intern, completed, wife, private, daughter, unable, bohrium,
# Nearest to joseph: catharine, terraced, milford, enoch, volcker, adopters, lito, sympathies,
# Nearest to notes: note, ventured, apok, prohibiting, publications, mohr, louisa, swiss,
# Nearest to consists: consisting, consecrate, superimposed, balances, independents, hamburgers, branch, duties,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8484 0.9447 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8320 0.9944 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8258 0.9854 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8187 0.9794 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8694 0.9260 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8243 0.9252 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9613 0.9189 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8908 0.9601 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8802 0.9948 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7861 0.9567 sec/batch
# Nearest to such: most, have, are, with, governmental, often, other, dispensing,
# Nearest to his: he, him, career, fell, acting, work, was, purport,
# Nearest to would: will, this, wanted, equivocal, print, okay, dispossessed, some,
# Nearest to its: the, is, it, of, part, a, in, has,
# Nearest to when: the, to, finalized, was, after, stalls, and, its,
# Nearest to may: iberians, arkady, features, january, diminished, contrition, kincaid, calorie,
# Nearest to with: to, a, in, such, of, three, from, some,
# Nearest to by: the, of, in, and, from, whose, all, which,
# Nearest to creation: itself, seaboard, its, manning, icosahedral, inmate, seated, footing,
# Nearest to road: streets, roads, smog, lipinski, pilsner, gustavus, rebar, uganda,
# Nearest to cost: microprocessors, brushes, chieftains, specialization, sleeper, profits, industry, divider,
# Nearest to accepted: andries, quatrain, informed, incarnation, indentation, martians, compulsory, questionable,
# Nearest to brother: completed, intern, private, phaedra, wife, bohrium, cmyk, daughter,
# Nearest to joseph: catharine, terraced, enoch, milford, bayle, adopters, theorizes, addington,
# Nearest to notes: note, ventured, apok, publications, prohibiting, mes, elongation, louisa,
# Nearest to consists: consisting, superimposed, are, consecrate, balances, independents, and, branch,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7829 0.9863 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8521 0.9663 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7363 0.9471 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8712 0.9697 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7938 1.0238 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8267 0.9487 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8596 0.5461 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8151 0.9465 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8222 0.9229 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8178 0.9480 sec/batch
# Nearest to such: most, have, are, with, often, governmental, other, non,
# Nearest to his: he, him, fell, was, son, career, caesarion, died,
# Nearest to would: this, will, print, wanted, some, dispossessed, okay, not,
# Nearest to its: the, is, it, part, of, a, incognita, respectively,
# Nearest to when: to, the, finalized, stalls, was, be, in, dependant,
# Nearest to may: iberians, features, arkady, diminished, angiosperm, january, is, calorie,
# Nearest to with: to, in, a, of, such, from, three, and,
# Nearest to by: the, of, in, and, from, whose, first, s,
# Nearest to creation: itself, its, icosahedral, seaboard, seated, manning, inmate, footing,
# Nearest to road: pilsner, smog, lipinski, roads, streets, rebar, gustavus, green,
# Nearest to cost: microprocessors, brushes, profits, chieftains, specialization, industry, divider, sleeper,
# Nearest to accepted: quatrain, incarnation, andries, questionable, informed, martians, indentation, appreciate,
# Nearest to brother: phaedra, wife, completed, daughter, intern, private, unable, allori,
# Nearest to joseph: catharine, enoch, milford, terraced, bayle, prevenient, schuster, adopters,
# Nearest to notes: note, ventured, apok, publications, elongation, heretofore, prohibiting, bracing,
# Nearest to consists: consisting, superimposed, consecrate, are, branch, balances, ilium, independents,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8300 16.9397 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7829 11.8717 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7992 19.5996 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7730 14.2903 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8693 12.9070 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8081 0.9493 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8317 0.9322 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6996 0.9309 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7882 0.9261 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7627 0.9264 sec/batch
# Nearest to such: most, are, have, with, often, and, governmental, for,
# Nearest to his: he, him, fell, career, son, father, caesarion, animatronic,
# Nearest to would: this, will, print, not, some, causes, that, wanted,
# Nearest to its: the, is, it, of, part, a, in, respectively,
# Nearest to when: finalized, to, be, dependant, the, stalls, after, as,
# Nearest to may: iberians, is, not, features, arkady, angiosperm, contrition, diminished,
# Nearest to with: to, a, in, of, such, three, and, it,
# Nearest to by: the, of, and, in, from, whose, s, all,
# Nearest to creation: itself, icosahedral, seaboard, manning, inmate, footing, verifiable, seated,
# Nearest to road: roads, streets, lipinski, pilsner, smog, gustavus, rebar, green,
# Nearest to cost: brushes, microprocessors, chieftains, profits, specialization, divider, sleeper, affixes,
# Nearest to accepted: questionable, incarnation, quatrain, informed, martians, andries, indentation, biologist,
# Nearest to brother: phaedra, completed, intern, private, cmyk, wife, leet, vba,
# Nearest to joseph: catharine, enoch, milford, terraced, theorizes, prevenient, mormonism, latter,
# Nearest to notes: note, ventured, publications, apok, bracing, cx, swiss, mes,
# Nearest to consists: consisting, are, superimposed, consecrate, and, branch, in, balances,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7180 0.9573 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8179 0.9148 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8043 0.9133 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8004 0.9190 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7832 0.9128 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8948 0.9157 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8324 0.9235 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7913 0.9197 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7953 0.9163 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8082 0.9207 sec/batch
# Nearest to such: most, are, have, with, often, governmental, for, other,
# Nearest to his: he, him, fell, career, father, auditioning, son, was,
# Nearest to would: this, will, print, wanted, not, surprising, to, some,
# Nearest to its: the, is, it, of, a, part, in, respectively,
# Nearest to when: to, finalized, be, the, stalls, was, after, hippodrome,
# Nearest to may: iberians, not, features, is, diminished, contrition, arkady, january,
# Nearest to with: to, in, a, of, such, and, three, it,
# Nearest to by: the, of, and, in, from, whose, s, as,
# Nearest to creation: itself, icosahedral, manning, seaboard, untethered, verifiable, footing, animations,
# Nearest to road: pilsner, roads, smog, lipinski, streets, gustavus, green, rebar,
# Nearest to cost: brushes, microprocessors, profits, chieftains, specialization, industry, columnists, divider,
# Nearest to accepted: informed, quatrain, incarnation, questionable, andries, compulsory, incomplete, ordinary,
# Nearest to brother: private, phaedra, intern, daughter, wife, cmyk, completed, allori,
# Nearest to joseph: catharine, milford, enoch, terraced, bayle, halford, theorizes, mormonism,
# Nearest to notes: note, ventured, publications, apok, bracing, oktoberfest, swiss, prohibiting,
# Nearest to consists: consisting, are, consecrate, superimposed, in, balances, branch, independents,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8565 0.9629 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8062 0.9685 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7956 1.5791 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8158 1.2056 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8516 1.1837 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8259 1.0945 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7984 0.9493 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8294 0.9163 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8145 0.9368 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7988 0.9289 sec/batch
# Nearest to such: most, are, have, with, and, other, governmental, often,
# Nearest to his: he, him, fell, career, son, father, acting, caesarion,
# Nearest to would: this, will, not, to, surprising, okay, some, wanted,
# Nearest to its: the, is, it, of, a, part, in, respectively,
# Nearest to when: to, the, be, and, finalized, is, also, that,
# Nearest to may: iberians, not, features, is, arkady, for, diminished, or,
# Nearest to with: to, in, a, of, and, such, three, some,
# Nearest to by: the, of, and, in, from, a, whose, as,
# Nearest to creation: itself, seaboard, manning, untethered, inmate, icosahedral, verifiable, footing,
# Nearest to road: roads, lipinski, pilsner, smog, streets, gustavus, rebar, motorway,
# Nearest to cost: brushes, microprocessors, profits, chieftains, divider, specialization, jihad, maintain,
# Nearest to accepted: incarnation, informed, quatrain, indentation, ordinary, compulsory, andries, questionable,
# Nearest to brother: phaedra, intern, private, wife, completed, daughter, allori, unable,
# Nearest to joseph: catharine, milford, enoch, terraced, bayle, theorizes, prevenient, ntc,
# Nearest to notes: note, ventured, publications, swiss, bracing, apok, mohr, cx,
# Nearest to consists: consisting, consecrate, are, superimposed, balances, in, ilium, xxxxx,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8226 0.9446 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7819 1.0353 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9018 0.9306 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8846 0.9257 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8635 1.0135 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8357 0.9387 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7444 0.9642 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8365 0.9388 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7099 1.0226 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8416 1.0040 sec/batch
# Nearest to such: most, are, have, with, often, governmental, other, non,
# Nearest to his: he, him, career, fell, auditioning, was, father, acting,
# Nearest to would: this, will, to, wanted, not, surprising, causes, print,
# Nearest to its: the, is, it, of, part, a, was, itself,
# Nearest to when: to, the, finalized, stalls, dependant, be, as, was,
# Nearest to may: iberians, not, arkady, is, january, features, in, diminished,
# Nearest to with: to, in, a, such, some, and, of, from,
# Nearest to by: the, of, in, and, a, s, as, whose,
# Nearest to creation: itself, inmate, seaboard, icosahedral, footing, seated, untethered, verifiable,
# Nearest to road: pilsner, roads, lipinski, smog, gustavus, uganda, streets, shimon,
# Nearest to cost: brushes, microprocessors, specialization, profits, divider, chieftains, jihad, columnists,
# Nearest to accepted: andries, incarnation, quatrain, informed, indentation, questionable, ordinary, martians,
# Nearest to brother: phaedra, private, intern, allori, chalons, narrowness, completed, wife,
# Nearest to joseph: catharine, milford, enoch, terraced, bayle, mormonism, theorizes, latter,
# Nearest to notes: note, ventured, publications, apok, bracing, absurdum, mes, swiss,
# Nearest to consists: consisting, superimposed, consecrate, are, and, balances, in, branch,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8151 0.9362 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8205 0.9137 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %%
embed_mat.shape
# Out:
# (63641, 300)

# %%
import pickle

# %%
with open('save_embed', 'wb') as f:
    pickle.dump(embed_mat, f)

# %%
# !ls -lS
# Out:
# total 213576
# -rw-r--r--  1 April  staff  76369362 May 31 14:47 save_embed
# -rw-r--r--  1 April  staff  31344016 May 30 18:09 text8.zip
# -rw-r--r--  1 April  staff    813006 May 30 17:31 Skip-Grams-Solution.ipynb
# -rw-r--r--  1 April  staff    807844 May 31 14:47 Skip-Gram_word2vec.ipynb
# -rw-r--r--  1 April  staff      2194 May 30 17:31 utils.py
# -rw-r--r--  1 April  staff       863 May 30 17:31 requirements.txt
# drwxr-xr-x  9 April  staff       288 May 30 17:31 assets
# drwxr-xr-x  6 April  staff       192 May 31 14:39 checkpoints
# drwxr-xr-x  3 April  staff        96 May 30 17:32 __pycache__
# drwxr-xr-x  3 April  staff        96 May 30 17:31 data

# %%
63641*300
# Out:
# 19092300

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
